# %%
import requests
import bs4 as bs
import numpy as np
import pandas as pd
import re
from html import unescape

# %%
processed_df = pd.read_csv('preprocessed_data.csv') #Final DF to be analyzed (will add new matches to this DF)
fighter_stats = pd.read_csv('data.csv') #compilation of existing fighter stats

# %%
#setting up... I will extract these columns from fighter_stats, for the fighters in the new matches...


columns_str = list(processed_df.columns) #all columns in preprocessed data
fighter_str = list(fighter_stats.columns) #all columns in the fighter stats

col_names_R = list(filter(None, [re.match(r'R.*', item) for item in columns_str])) 
col_names_R = [item.group(0) for item in col_names_R]

col_names_B = list(filter(None, [re.match(r'B.*', item) for item in columns_str])) 
col_names_B = [item.group(0) for item in col_names_B]

fighter_R = list(filter(None, [re.match(r'R.*', item) for item in fighter_str])) 
fighter_R = [item.group(0) for item in fighter_R]
fighter_R.remove('Referee') #columns for Fighter_R

fighter_B = list(filter(None, [re.match(r'B.*', item) for item in fighter_str])) 
fighter_B = [item.group(0) for item in fighter_B] #columns for Fighter_B

# %%
url = 'http://ufcstats.com/statistics/events/completed'

# %%
page = requests.get(url)

# %%
soup = bs.BeautifulSoup(page.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js ie8 lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
#     Stats | UFC
#   </title>
# <meta content="" name="description"/>
# <meta content="" name="viewport"/>
# <link href="/blocks/main.css?ver=919691" rel="stylesheet"/>
# <script src="/js/vendor/modernizr-2.6.2.min.js"></script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-2855164-1', 'auto');
#     ga('send', 'pageview');
#   </script>
# </head>
# <body class="b-page" data-link="home">
# <header class="b-head">
# <div class="b-head__nav-bar">
# <div class="l-page__container">
# <a class="b-head__logo" href="/">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/ufc-stats-logo.png"/>
# </a>
# <menu class="b-head__menu">
# <li class="b-head__item b-head__item_state_current">
# <a class="b-head__menu-link">
#               EVENTS &amp; FIGHTS
#             </a>
# </li>
# <li class="b-head__item">
# <a class="b-head__menu-link" href="/statistics/fighters">
#               FIGHTERS
#             </a>
# </li>
# <li class="b-head__item">
# <a class="b-head__menu-link" href="/fighter-stats">
#               STAT LEADERS
#             </a>
# </li>
# </menu>
# </div>
# </div>
# <div class="b-head__sub-nav">
# </div>
# </header>
# <section class="b-statistics__section">
# <div class="l-page__container">
# <div class="b-statistics__inner">
# <div class="b-statistics__entry">
# <div class="b-statistics__content clearfix">
# <h2 class="b-content__title b-content__title_type_left">
#             Events &amp; Fights
#           </h2>
# <div class="b-statistics__search-inner">
# <form action="/statistics/events/search" class="b-statistics__search">
# <label>
# <input class="b-statistics__search-field" name="query" placeholder="Enter Event or Organization" type="text" value=""/>
# </label>
# <button class="b-statistics__search-btn" type="submit"></button>
# </form>
# </div>
# </div>
# <ul class="b-statistics__sub-tabs">
# <li class="b-statistics__sub-tabs-item b-statistics__sub-tabs-item_state_current">
# <a class="b-statistics__sub-tabs-link" href="http://ufcstats.com/statistics/events/completed">
#             Completed
#             <i class="b-statistics__sub-tabs-corner b-statistics__sub-tabs-corner_type_down"></i>
# </a>
# </li>
# <li class="b-statistics__sub-tabs-item">
# <a class="b-statistics__sub-tabs-link" href="http://ufcstats.com/statistics/events/upcoming">
#             Upcoming
#             <i class="b-statistics__sub-tabs-corner b-statistics__sub-tabs-corner_type_down"></i>
# </a>
# </li>
# </ul>
# <div class="b-statistics__sub-inner">
# <div class="b-statistics__sub-entry">
# <table class="b-statistics__table-events">
# <thead class="b-statistics__table-caption">
# <tr class="b-statistics__table-row">
# <th class="b-statistics__table-col">
#                   Name/date
#                 </th>
# <th class="b-statistics__table-col">
#                   Location
#                 </th>
# </tr>
# </thead>
# <tbody>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col_type_clear"></td>
# </tr>
# <tr class="b-statistics__table-row_type_first">
# <td class="b-statistics__table-col">
# <img class="b-statistics__icon" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/next.png">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_white" href="http://ufcstats.com/event-details/74fefd43f073cd2f">
#                           UFC Fight Night: Edgar vs. The Korean Zombie
#                         </a>
# <span class="b-statistics__date">
#                           December 21, 2019
#                         </span>
# </i>
# </img></td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Busan, South Korea
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/4565d435005319c0">
#                           UFC 245: Usman vs. Covington
#                         </a>
# <span class="b-statistics__date">
#                           December 14, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/b09890ba7ce1d1e2">
#                           UFC Fight Night: Overeem vs. Rozenstruik
#                         </a>
# <span class="b-statistics__date">
#                           December 07, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Washington, DC, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/81ca2c245b19b3c5">
#                           UFC Fight Night: Blachowicz vs. Jacare
#                         </a>
# <span class="b-statistics__date">
#                           November 16, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Sao Paulo, Sao Paulo, Brazil
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/8d5daf67983b65ba">
#                           UFC Fight Night: Zabit vs. Kattar
#                         </a>
# <span class="b-statistics__date">
#                           November 09, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Moscow, Moscow, Russia
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/fd87b1bbfcde9d5e">
#                           UFC 244: Masvidal vs. Diaz
#                         </a>
# <span class="b-statistics__date">
#                           November 02, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     New York City, New York, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/df05aa15b2d66f57">
#                           UFC Fight Night: Maia vs. Askren
#                         </a>
# <span class="b-statistics__date">
#                           October 26, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Kallang, Singapore
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/3ae10ac4df3df05c">
#                           UFC Fight Night: Reyes vs. Weidman
#                         </a>
# <span class="b-statistics__date">
#                           October 18, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Boston, Massachusetts, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/0941df56f6ac954b">
#                           UFC Fight Night: Joanna vs. Waterson
#                         </a>
# <span class="b-statistics__date">
#                           October 12, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Tampa, Florida, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/3cf68c1d17f66af7">
#                           UFC 243: Whittaker vs. Adesanya
#                         </a>
# <span class="b-statistics__date">
#                           October 05, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Melbourne, Victoria, Australia
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/1bf49bf829964144">
#                           UFC Fight Night: Hermansson vs. Cannonier
#                         </a>
# <span class="b-statistics__date">
#                           September 28, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Copenhagen, Denmark
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/94a5aaf573f780ad">
#                           UFC Fight Night: Rodriguez vs. Stephens
#                         </a>
# <span class="b-statistics__date">
#                           September 21, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Mexico City, Distrito Federal, Mexico
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/4834ff149dc9542a">
#                           UFC Fight Night: Cowboy vs. Gaethje
#                         </a>
# <span class="b-statistics__date">
#                           September 14, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Vancouver, British Columbia, Canada
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/a79bfbc01b2264d6">
#                           UFC 242: Khabib vs. Poirier
#                         </a>
# <span class="b-statistics__date">
#                           September 07, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Abu Dhabi, Abu Dhabi, United Arab Emirates
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/2c104b7e59a72629">
#                           UFC Fight Night: Andrade vs. Zhang
#                         </a>
# <span class="b-statistics__date">
#                           August 31, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Shenzhen, Guangdong, China
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/70167689d6a01793">
#                           UFC 241: Cormier vs. Miocic 2
#                         </a>
# <span class="b-statistics__date">
#                           August 17, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Anaheim, California, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/e5d03e4d966126bd">
#                           UFC Fight Night: Shevchenko vs. Carmouche 2
#                         </a>
# <span class="b-statistics__date">
#                           August 10, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Montevideo, Uruguay
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/03da33a102d9a45f">
#                           UFC Fight Night: Covington vs. Lawler
#                         </a>
# <span class="b-statistics__date">
#                           August 03, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Newark, New Jersey, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/abcf7e55a0a9ed89">
#                           UFC 240: Holloway vs. Edgar
#                         </a>
# <span class="b-statistics__date">
#                           July 27, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Edmonton, Alberta, Canada
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/9e0f28d1f639ad73">
#                           UFC Fight Night: Dos Anjos vs. Edwards
#                         </a>
# <span class="b-statistics__date">
#                           July 20, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     San Antonio, Texas, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/2f8f3c69522db931">
#                           UFC Fight Night: De Randamie vs. Ladd
#                         </a>
# <span class="b-statistics__date">
#                           July 13, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Sacramento, California, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/6c9383ffab2725a5">
#                           UFC 239: Jones vs. Santos
#                         </a>
# <span class="b-statistics__date">
#                           July 06, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/c0c1bc0766df4c00">
#                           UFC Fight Night: Ngannou vs. Dos Santos
#                         </a>
# <span class="b-statistics__date">
#                           June 29, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Minneapolis, Minnesota, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/b16a7e6a627e9789">
#                           UFC Fight Night: Moicano vs. The Korean Zombie
#                         </a>
# <span class="b-statistics__date">
#                           June 22, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Greenville, South Carolina, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/e31502e3f79d00c5">
#                           UFC 238: Cejudo vs. Moraes
#                         </a>
# <span class="b-statistics__date">
#                           June 08, 2019
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Chicago, Illinois, USA
#                   </td>
# </tr>
# </tbody>
# </table>
# <div class="b-statistics__paginate-inner">
# <ul class="b-statistics__paginate">
# <li class="b-statistics__paginate-item b-statistics__paginate-item_state_current">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed">
#             1
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=2">
#             2
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=3">
#             3
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=4">
#             4
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=5">
#             5
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=6">
#             6
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=7">
#             7
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=8">
#             8
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <span class="b-statistics__paginate-link">
#             ...
#           </span>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=37">
#             37
#           </a>
# </li>
# <li class="b-statistics__paginate-item">
# <a class="b-statistics__paginate-link" href="http://ufcstats.com/statistics/events/completed?page=all">
#             All
#           </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <footer class="b-foot">
# <div class="b-foot__inner">
# <div class="l-page__container clearfix">
# <div class="b-foot__right">
# <div class="b-foot__list-inner">
# <h4 class="b-foot__list-title">
#             Navigation
#           </h4>
# <ul class="b-foot__list">
# <li class="b-foot__item">
# <a class="b-foot__link" href="/statistics/events/">
#                 Events &amp; Fights
#               </a>
# </li>
# <li class="b-foot__item">
# <a class="b-foot__link" href="/statistics/fighters">
#                 Fighters
#               </a>
# </li>
# <li class="b-foot__item">
# <a class="b-foot__link" href="/fighter-stats">
#                 Stat Leaders
#               </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="b-foot__logo">
# <a href="/">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/ufc-stats-foot-logo.png"/>
# </a>
# <div class="b-foot__copy-inner">
#           © All Rights Reserved |
#           <a class="b-foot__copy-link" href="https://ufc.com/terms" target="_blank">Terms of Use</a> |
#           <a class="b-foot__copy-link" href="https://ufc.com/privacy-policy" target="_blank">Privacy Policy</a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
# <script src="http://code.jquery.com/jquery-1.9.1.js"></script>
# <script src="http://code.jquery.com/ui/1.10.3/jquery-ui.js"></script>
# <link href="http://code.jquery.com/ui/1.10.3/themes/smoothness/jquery-ui.css" rel="stylesheet">
# <script>window.jQuery || document.write('<script src="/js/vendor/jquery-1.10.2.min.js"><\/script>')</script>
# <script src="/js/vendor/jquery.validate.min.js" type="text/javascript"></script>
# <script src="/js/plugins.js"></script>
# <script src="/js/main.js?ver=919897"></script>
# <script type="text/javascript">
#     $(document).ready(function () {
#         $(function () {
#             $("#dialog").dialog({
#
#                 autoOpen: false,
#                 modal: true,
#                 show: {
#                     effect: "blind",
#                     duration: 1000
#                 },
#                 hide: {
#                     effect: "fold",
#                     duration: 1000
#                 }
#
#             });
#         });
#     }
#
#     );
#     $("#opener").click(function () {
#         $("#dialog").dialog("open");
#     });
#     $("#opener").click(function () {
#         var state = true;
#         if (state) {
#             $("#dialog").animate({
#                 backgroundColor: "white",
#                 color: "black"
#
#             }, 1000);
#         }
#     });
#
# </script>
# <script type="text/javascript">
#
#  /*window.onload = function (){
#      // location.pathname.split( '/' )
#      theUrl = window.location.host;
#
#
#      if(theUrl === 'hosteddb.fightmetric.com'){
#          window.location.replace("http://www.fightmetric.com/statistics/events/upcoming");
#      }
#
#      //alert(theUrl);
#   }*/
#   //window.onpaint = handleHosted;
# </script>
# </link></body>
# </html>

# %%
#List of more urls to scrape:
detail_urls = [] #this grabs urls for each day recorded
for url in soup.find_all(class_='b-link b-link_style_black'):
    detail_urls.append(url['href'])

# %%
detail_urls = detail_urls[0:2]
detail_urls
# Out:
# ['http://ufcstats.com/event-details/4565d435005319c0',
#  'http://ufcstats.com/event-details/b09890ba7ce1d1e2']

# %%
def extract_fights_df(url):
    #setup the correct url page
    day = requests.get(url)
    soup = bs.BeautifulSoup(day.text, 'html.parser')
    
    #grab the table using pandas read_html
    a = pd.read_html(str(soup.find(class_='b-fight-details__table b-fight-details__table_style_margin-top b-fight-details__table_type_event-details js-fight-table')))
    df = a[0]
    
    #expand the names... .we'll need to concatenate them manually to match...
    df = df.drop(['Str', 'Td', 'Sub', 'Pass'], axis = 1)
 
    return df

# %%
#Let's extract fights from multiple pages:
combined_df = pd.DataFrame()
for url in detail_urls:
    combined_df = pd.concat([combined_df, extract_fights_df(url)], axis = 0)

# %%
combined_df = combined_df.reset_index(drop = True)
combined_df
# Out:
#           W/L                                  Fighter          Weight class  \
# 0         win            Kamaru Usman  Colby Covington          Welterweight
# 1         win      Alexander Volkanovski  Max Holloway         Featherweight
# 2         win       Amanda Nunes  Germaine de Randamie  Women's Bantamweight
# 3         win                 Marlon Moraes  Jose Aldo          Bantamweight
# 4         win                   Petr Yan  Urijah Faber          Bantamweight
# 5         win                   Geoff Neal  Mike Perry          Welterweight
# 6         win              Irene Aldana  Ketlen Vieira  Women's Bantamweight
# 7         win             Omari Akhmedov  Ian Heinisch          Middleweight
# 8         win                 Matt Brown  Ben Saunders          Welterweight
# 9         win              Chase Hooper  Daniel Teymur         Featherweight
# 10        win          Brandon Moreno  Kai Kara-France             Flyweight
# 11        win              Jessica Eye  Viviane Araujo     Women's Flyweight
# 12        win         Punahele Soriano  Oskar Piechota          Middleweight
# 13        win  Jairzinho Rozenstruik  Alistair Overeem           Heavyweight
# 14  draw draw       Marina Rodriguez  Cynthia Calvillo   Women's Strawweight
# 15        win              Ben Rothwell  Stefan Struve           Heavyweight
# 16        win              Aspen Ladd  Yana Kunitskaya  Women's Bantamweight
# 17  draw draw                Cody Stamann  Song Yadong          Bantamweight
# 18        win                    Rob Font  Ricky Simon          Bantamweight
# 19        win                  Tim Means  Thiago Alves          Welterweight
# 20        win         Billy Quarantillo  Jacob Kilburn         Featherweight
# 21        win              Bryce Mitchell  Matt Sayles         Featherweight
# 22        win                  Joe Solecki  Matt Wiman           Lightweight
# 23        win          Virna Jandiroba  Mallory Martin   Women's Strawweight
# 24        win            Makhmud Muradov  Trevor Smith          Middleweight
#
#                    Method  Round  Time
# 0           KO/TKO  Punch      5  4:10
# 1                   U-DEC      5  5:00
# 2                   U-DEC      5  5:00
# 3                   S-DEC      3  5:00
# 4            KO/TKO  Kick      3  0:43
# 5         KO/TKO  Punches      1  1:30
# 6           KO/TKO  Punch      1  4:51
# 7                   U-DEC      3  5:00
# 8         KO/TKO  Punches      2  4:55
# 9          KO/TKO  Elbows      1  4:34
# 10                  U-DEC      3  5:00
# 11                  U-DEC      3  5:00
# 12          KO/TKO  Punch      1  3:17
# 13          KO/TKO  Punch      5  4:56
# 14                  M-DEC      3  5:00
# 15        KO/TKO  Punches      2  4:57
# 16        KO/TKO  Punches      3  0:33
# 17                  M-DEC      3  5:00
# 18                  U-DEC      3  5:00
# 19  SUB  Guillotine Choke      1  2:38
# 20    SUB  Triangle Choke      2  3:18
# 21             SUB  Other      1  4:20
# 22                  U-DEC      3  5:00
# 23  SUB  Rear Naked Choke      2  1:16
# 24          KO/TKO  Punch      3  4:09

# %%
def split_name(name):
    indices = [(m.start(0), m.end(0)) for m in re.finditer(r'\s\s', name)][0]
    name1 = name[:indices[0]]
    name2 = name[indices[1]:]
    return [name1, name2]

# %%
#splits the names in the Fighter column

winner = []
loser = []

for item in combined_df['Fighter']:
    names = split_name(item)
    winner.append(names[0])
    loser.append(names[1])

# %%
combined_df['R_fighter'] = winner
combined_df['B_fighter'] = loser

# %%
combined_df
# Out:
#           W/L                                  Fighter          Weight class  \
# 0         win            Kamaru Usman  Colby Covington          Welterweight
# 1         win      Alexander Volkanovski  Max Holloway         Featherweight
# 2         win       Amanda Nunes  Germaine de Randamie  Women's Bantamweight
# 3         win                 Marlon Moraes  Jose Aldo          Bantamweight
# 4         win                   Petr Yan  Urijah Faber          Bantamweight
# 5         win                   Geoff Neal  Mike Perry          Welterweight
# 6         win              Irene Aldana  Ketlen Vieira  Women's Bantamweight
# 7         win             Omari Akhmedov  Ian Heinisch          Middleweight
# 8         win                 Matt Brown  Ben Saunders          Welterweight
# 9         win              Chase Hooper  Daniel Teymur         Featherweight
# 10        win          Brandon Moreno  Kai Kara-France             Flyweight
# 11        win              Jessica Eye  Viviane Araujo     Women's Flyweight
# 12        win         Punahele Soriano  Oskar Piechota          Middleweight
# 13        win  Jairzinho Rozenstruik  Alistair Overeem           Heavyweight
# 14  draw draw       Marina Rodriguez  Cynthia Calvillo   Women's Strawweight
# 15        win              Ben Rothwell  Stefan Struve           Heavyweight
# 16        win              Aspen Ladd  Yana Kunitskaya  Women's Bantamweight
# 17  draw draw                Cody Stamann  Song Yadong          Bantamweight
# 18        win                    Rob Font  Ricky Simon          Bantamweight
# 19        win                  Tim Means  Thiago Alves          Welterweight
# 20        win         Billy Quarantillo  Jacob Kilburn         Featherweight
# 21        win              Bryce Mitchell  Matt Sayles         Featherweight
# 22        win                  Joe Solecki  Matt Wiman           Lightweight
# 23        win          Virna Jandiroba  Mallory Martin   Women's Strawweight
# 24        win            Makhmud Muradov  Trevor Smith          Middleweight
#
#                    Method  Round  Time              R_fighter  \
# 0           KO/TKO  Punch      5  4:10           Kamaru Usman
# 1                   U-DEC      5  5:00  Alexander Volkanovski
# 2                   U-DEC      5  5:00           Amanda Nunes
# 3                   S-DEC      3  5:00          Marlon Moraes
# 4            KO/TKO  Kick      3  0:43               Petr Yan
# 5         KO/TKO  Punches      1  1:30             Geoff Neal
# 6           KO/TKO  Punch      1  4:51           Irene Aldana
# 7                   U-DEC      3  5:00         Omari Akhmedov
# 8         KO/TKO  Punches      2  4:55             Matt Brown
# 9          KO/TKO  Elbows      1  4:34           Chase Hooper
# 10                  U-DEC      3  5:00         Brandon Moreno
# 11                  U-DEC      3  5:00            Jessica Eye
# 12          KO/TKO  Punch      1  3:17       Punahele Soriano
# 13          KO/TKO  Punch      5  4:56  Jairzinho Rozenstruik
# 14                  M-DEC      3  5:00       Marina Rodriguez
# 15        KO/TKO  Punches      2  4:57           Ben Rothwell
# 16        KO/TKO  Punches      3  0:33             Aspen Ladd
# 17                  M-DEC      3  5:00           Cody Stamann
# 18                  U-DEC      3  5:00               Rob Font
# 19  SUB  Guillotine Choke      1  2:38              Tim Means
# 20    SUB  Triangle Choke      2  3:18      Billy Quarantillo
# 21             SUB  Other      1  4:20         Bryce Mitchell
# 22                  U-DEC      3  5:00            Joe Solecki
# 23  SUB  Rear Naked Choke      2  1:16        Virna Jandiroba
# 24          KO/TKO  Punch      3  4:09        Makhmud Muradov
#
#                B_fighter
# 0        Colby Covington
# 1           Max Holloway
# 2   Germaine de Randamie
# 3              Jose Aldo
# 4           Urijah Faber
# 5             Mike Perry
# 6          Ketlen Vieira
# 7           Ian Heinisch
# 8           Ben Saunders
# 9          Daniel Teymur
# 10       Kai Kara-France
# 11        Viviane Araujo
# 12        Oskar Piechota
# 13      Alistair Overeem
# 14      Cynthia Calvillo
# 15         Stefan Struve
# 16       Yana Kunitskaya
# 17           Song Yadong
# 18           Ricky Simon
# 19          Thiago Alves
# 20         Jacob Kilburn
# 21           Matt Sayles
# 22            Matt Wiman
# 23        Mallory Martin
# 24          Trevor Smith

# %%
def extract_recent_fight(fighter): #This function returns all the stats from fighter's most recent fight

    try:
        R_df = pd.DataFrame(fighter_stats[fighter_stats['R_fighter'] == fighter])
    except:
        print('Fighter not in list R')
    
    try: 
        B_df = pd.DataFrame(fighter_stats[fighter_stats['B_fighter'] == fighter])
    except:
        print('Fighter not in list B')
        
    combined_df = pd.concat([R_df, B_df], axis = 0)
    combined_df = combined_df.sort_values('date', ascending = False)
        
    return combined_df.iloc[0, ].copy()

# %%
def recent_fight_stats(fighter): #This function returns the stats for only the fighter's most recent stats:
    fight = extract_recent_fight(fighter)
    if fight['R_fighter'] == fighter:
        return fight[fighter_R]
        
    if fight['B_fighter'] == fighter:    
        return fight[fighter_B]

# %%
#These functions take the fighter's most recent stats and changes the colnames to match the final template:

def name_columns_R(fighter):
    data = pd.DataFrame(recent_fight_stats(fighter)).transpose()
    data.columns = fighter_R
    
    return data
    
def name_columns_B(fighter):
    data = pd.DataFrame(recent_fight_stats(fighter)).transpose()
    data.columns = fighter_B
    
    return data
    
def remove_space(text):
    new_text = unescape(text)
    return re.sub(r'\s\s+'," ", new_text)

# %%
fighter_R_stats = pd.DataFrame()
fighter_B_stats = pd.DataFrame()

for (r, b) in zip(combined_df['R_fighter'], combined_df['B_fighter']):
    try:
        fighter_R_stats = pd.concat([fighter_R_stats, pd.DataFrame(name_columns_R(r))])
    except:
        fighter_R_stats = fighter_R_stats.append(pd.Series(), ignore_index = True)
        
    try:
        fighter_B_stats = pd.concat([fighter_B_stats, pd.DataFrame(name_columns_B(b))])
    except:
        fighter_B_stats = fighter_B_stats.append(pd.Series(), ignore_index = True)

# %%
fighter_R_stats = fighter_R_stats.reset_index(drop = True)
fighter_B_stats = fighter_B_stats.reset_index(drop = True)

# %%
combined_template = pd.concat([fighter_R_stats, fighter_B_stats], axis = 1)

# %%
combined_template.shape
# Out:
# (25, 138)

# %%
combined_template = pd.concat([combined_df, combined_template], axis = 1)
combined_template
# Out:
#           W/L                                  Fighter          Weight class  \
# 0         win            Kamaru Usman  Colby Covington          Welterweight
# 1         win      Alexander Volkanovski  Max Holloway         Featherweight
# 2         win       Amanda Nunes  Germaine de Randamie  Women's Bantamweight
# 3         win                 Marlon Moraes  Jose Aldo          Bantamweight
# 4         win                   Petr Yan  Urijah Faber          Bantamweight
# 5         win                   Geoff Neal  Mike Perry          Welterweight
# 6         win              Irene Aldana  Ketlen Vieira  Women's Bantamweight
# 7         win             Omari Akhmedov  Ian Heinisch          Middleweight
# 8         win                 Matt Brown  Ben Saunders          Welterweight
# 9         win              Chase Hooper  Daniel Teymur         Featherweight
# 10        win          Brandon Moreno  Kai Kara-France             Flyweight
# 11        win              Jessica Eye  Viviane Araujo     Women's Flyweight
# 12        win         Punahele Soriano  Oskar Piechota          Middleweight
# 13        win  Jairzinho Rozenstruik  Alistair Overeem           Heavyweight
# 14  draw draw       Marina Rodriguez  Cynthia Calvillo   Women's Strawweight
# 15        win              Ben Rothwell  Stefan Struve           Heavyweight
# 16        win              Aspen Ladd  Yana Kunitskaya  Women's Bantamweight
# 17  draw draw                Cody Stamann  Song Yadong          Bantamweight
# 18        win                    Rob Font  Ricky Simon          Bantamweight
# 19        win                  Tim Means  Thiago Alves          Welterweight
# 20        win         Billy Quarantillo  Jacob Kilburn         Featherweight
# 21        win              Bryce Mitchell  Matt Sayles         Featherweight
# 22        win                  Joe Solecki  Matt Wiman           Lightweight
# 23        win          Virna Jandiroba  Mallory Martin   Women's Strawweight
# 24        win            Makhmud Muradov  Trevor Smith          Middleweight
#
#                    Method  Round  Time              R_fighter  \
# 0           KO/TKO  Punch      5  4:10           Kamaru Usman
# 1                   U-DEC      5  5:00  Alexander Volkanovski
# 2                   U-DEC      5  5:00           Amanda Nunes
# 3                   S-DEC      3  5:00          Marlon Moraes
# 4            KO/TKO  Kick      3  0:43               Petr Yan
# 5         KO/TKO  Punches      1  1:30             Geoff Neal
# 6           KO/TKO  Punch      1  4:51           Irene Aldana
# 7                   U-DEC      3  5:00         Omari Akhmedov
# 8         KO/TKO  Punches      2  4:55             Matt Brown
# 9          KO/TKO  Elbows      1  4:34           Chase Hooper
# 10                  U-DEC      3  5:00         Brandon Moreno
# 11                  U-DEC      3  5:00            Jessica Eye
# 12          KO/TKO  Punch      1  3:17       Punahele Soriano
# 13          KO/TKO  Punch      5  4:56  Jairzinho Rozenstruik
# 14                  M-DEC      3  5:00       Marina Rodriguez
# 15        KO/TKO  Punches      2  4:57           Ben Rothwell
# 16        KO/TKO  Punches      3  0:33             Aspen Ladd
# 17                  M-DEC      3  5:00           Cody Stamann
# 18                  U-DEC      3  5:00               Rob Font
# 19  SUB  Guillotine Choke      1  2:38              Tim Means
# 20    SUB  Triangle Choke      2  3:18      Billy Quarantillo
# 21             SUB  Other      1  4:20         Bryce Mitchell
# 22                  U-DEC      3  5:00            Joe Solecki
# 23  SUB  Rear Naked Choke      2  1:16        Virna Jandiroba
# 24          KO/TKO  Punch      3  4:09        Makhmud Muradov
#
#                B_fighter              R_fighter R_current_lose_streak  ...  \
# 0        Colby Covington           Kamaru Usman                     0  ...
# 1           Max Holloway  Alexander Volkanovski                     0  ...
# 2   Germaine de Randamie           Amanda Nunes                     0  ...
# 3              Jose Aldo          Marlon Moraes                     0  ...
# 4           Urijah Faber               Petr Yan                     0  ...
# 5             Mike Perry             Geoff Neal                     0  ...
# 6          Ketlen Vieira           Irene Aldana                     0  ...
# 7           Ian Heinisch         Omari Akhmedov                     1  ...
# 8           Ben Saunders             Matt Brown                     3  ...
# 9          Daniel Teymur                    NaN                   NaN  ...
# 10       Kai Kara-France         Brandon Moreno                     1  ...
# 11        Viviane Araujo            Jessica Eye                     0  ...
# 12        Oskar Piechota                    NaN                   NaN  ...
# 13      Alistair Overeem  Jairzinho Rozenstruik                     0  ...
# 14      Cynthia Calvillo       Marina Rodriguez                     1  ...
# 15         Stefan Struve           Ben Rothwell                     1  ...
# 16       Yana Kunitskaya             Aspen Ladd                     0  ...
# 17           Song Yadong           Cody Stamann                     1  ...
# 18           Ricky Simon               Rob Font                     1  ...
# 19          Thiago Alves              Tim Means                     0  ...
# 20         Jacob Kilburn                    NaN                   NaN  ...
# 21           Matt Sayles         Bryce Mitchell                     0  ...
# 22            Matt Wiman                    NaN                   NaN  ...
# 23        Mallory Martin        Virna Jandiroba                     0  ...
# 24          Trevor Smith                    NaN                   NaN  ...
#
#    B_win_by_Decision_Unanimous B_win_by_KO/TKO B_win_by_Submission  \
# 0                            4               2                   2
# 1                            4               8                   2
# 2                            1               2                   0
# 3                            6               4                   0
# 4                            3               0                   6
# 5                            0               4                   0
# 6                            1               0                   1
# 7                            1               0                   0
# 8                            2               3                   3
# 9                            0               0                   0
# 10                           1               0                   0
# 11                           0               0                   0
# 12                           1               1                   0
# 13                           2               6                   0
# 14                           1               0                   3
# 15                           1               5                   5
# 16                           1               0                   0
# 17                           0               1                   1
# 18                           1               1                   0
# 19                           5               7                   1
# 20                         NaN             NaN                 NaN
# 21                           0               0                   0
# 22                           4               2                   3
# 23                         NaN             NaN                 NaN
# 24                           4               0                   0
#
#    B_win_by_TKO_Doctor_Stoppage B_wins  B_Stance B_Height_cms B_Reach_cms  \
# 0                             0      8  Orthodox       180.34      182.88
# 1                             1     16  Orthodox       180.34      175.26
# 2                             0      4  Orthodox       175.26      180.34
# 3                             0     10  Orthodox       170.18       177.8
# 4                             0      9  Orthodox       167.64      170.18
# 5                             0      5  Orthodox        177.8      180.34
# 6                             0      3  Orthodox       172.72      172.72
# 7                             0      1  Orthodox       180.34      182.88
# 8                             0      9  Orthodox       187.96      195.58
# 9                             0      0  Orthodox        165.1      175.26
# 10                            0      1  Orthodox        165.1      175.26
# 11                            0      0  Orthodox       162.56      172.72
# 12                            0      2  Southpaw       182.88      193.04
# 13                            0      9  Orthodox       193.04       203.2
# 14                            0      4  Orthodox       162.56      162.56
# 15                            0     12  Orthodox       210.82      213.36
# 16                            0      1  Orthodox       167.64      172.72
# 17                            0      2  Orthodox       172.72      170.18
# 18                            0      2  Orthodox       167.64      175.26
# 19                            1     15  Orthodox       175.26       177.8
# 20                          NaN    NaN       NaN          NaN         NaN
# 21                            0      0  Orthodox       170.18      172.72
# 22                            0      9  Orthodox        177.8      172.72
# 23                          NaN    NaN       NaN          NaN         NaN
# 24                            0      5  Orthodox        190.5       190.5
#
#    B_Weight_lbs B_age
# 0           170    30
# 1           155    27
# 2           135    34
# 3           145    32
# 4           135    37
# 5           170    27
# 6           135    26
# 7           185    30
# 8           170    36
# 9           145    31
# 10          125    25
# 11          135    32
# 12          185    28
# 13          265    38
# 14          115    31
# 15          265    31
# 16          135    29
# 17          135    20
# 18          135    26
# 19          170    35
# 20          NaN   NaN
# 21          145    25
# 22          155    31
# 23          NaN   NaN
# 24          185    37
#
# [25 rows x 146 columns]

# %%
combined_template.dropna(how = 'all', inplace = True)
combined_template.drop(combined_df.columns[0], axis=1, inplace = True)
combined_template
# Out:
#                                     Fighter          Weight class  \
# 0             Kamaru Usman  Colby Covington          Welterweight
# 1       Alexander Volkanovski  Max Holloway         Featherweight
# 2        Amanda Nunes  Germaine de Randamie  Women's Bantamweight
# 3                  Marlon Moraes  Jose Aldo          Bantamweight
# 4                    Petr Yan  Urijah Faber          Bantamweight
# 5                    Geoff Neal  Mike Perry          Welterweight
# 6               Irene Aldana  Ketlen Vieira  Women's Bantamweight
# 7              Omari Akhmedov  Ian Heinisch          Middleweight
# 8                  Matt Brown  Ben Saunders          Welterweight
# 9               Chase Hooper  Daniel Teymur         Featherweight
# 10          Brandon Moreno  Kai Kara-France             Flyweight
# 11              Jessica Eye  Viviane Araujo     Women's Flyweight
# 12         Punahele Soriano  Oskar Piechota          Middleweight
# 13  Jairzinho Rozenstruik  Alistair Overeem           Heavyweight
# 14       Marina Rodriguez  Cynthia Calvillo   Women's Strawweight
# 15              Ben Rothwell  Stefan Struve           Heavyweight
# 16              Aspen Ladd  Yana Kunitskaya  Women's Bantamweight
# 17                Cody Stamann  Song Yadong          Bantamweight
# 18                    Rob Font  Ricky Simon          Bantamweight
# 19                  Tim Means  Thiago Alves          Welterweight
# 20         Billy Quarantillo  Jacob Kilburn         Featherweight
# 21              Bryce Mitchell  Matt Sayles         Featherweight
# 22                  Joe Solecki  Matt Wiman           Lightweight
# 23          Virna Jandiroba  Mallory Martin   Women's Strawweight
# 24            Makhmud Muradov  Trevor Smith          Middleweight
#
#                    Method  Round  Time              R_fighter  \
# 0           KO/TKO  Punch      5  4:10           Kamaru Usman
# 1                   U-DEC      5  5:00  Alexander Volkanovski
# 2                   U-DEC      5  5:00           Amanda Nunes
# 3                   S-DEC      3  5:00          Marlon Moraes
# 4            KO/TKO  Kick      3  0:43               Petr Yan
# 5         KO/TKO  Punches      1  1:30             Geoff Neal
# 6           KO/TKO  Punch      1  4:51           Irene Aldana
# 7                   U-DEC      3  5:00         Omari Akhmedov
# 8         KO/TKO  Punches      2  4:55             Matt Brown
# 9          KO/TKO  Elbows      1  4:34           Chase Hooper
# 10                  U-DEC      3  5:00         Brandon Moreno
# 11                  U-DEC      3  5:00            Jessica Eye
# 12          KO/TKO  Punch      1  3:17       Punahele Soriano
# 13          KO/TKO  Punch      5  4:56  Jairzinho Rozenstruik
# 14                  M-DEC      3  5:00       Marina Rodriguez
# 15        KO/TKO  Punches      2  4:57           Ben Rothwell
# 16        KO/TKO  Punches      3  0:33             Aspen Ladd
# 17                  M-DEC      3  5:00           Cody Stamann
# 18                  U-DEC      3  5:00               Rob Font
# 19  SUB  Guillotine Choke      1  2:38              Tim Means
# 20    SUB  Triangle Choke      2  3:18      Billy Quarantillo
# 21             SUB  Other      1  4:20         Bryce Mitchell
# 22                  U-DEC      3  5:00            Joe Solecki
# 23  SUB  Rear Naked Choke      2  1:16        Virna Jandiroba
# 24          KO/TKO  Punch      3  4:09        Makhmud Muradov
#
#                B_fighter              R_fighter R_current_lose_streak  \
# 0        Colby Covington           Kamaru Usman                     0
# 1           Max Holloway  Alexander Volkanovski                     0
# 2   Germaine de Randamie           Amanda Nunes                     0
# 3              Jose Aldo          Marlon Moraes                     0
# 4           Urijah Faber               Petr Yan                     0
# 5             Mike Perry             Geoff Neal                     0
# 6          Ketlen Vieira           Irene Aldana                     0
# 7           Ian Heinisch         Omari Akhmedov                     1
# 8           Ben Saunders             Matt Brown                     3
# 9          Daniel Teymur                    NaN                   NaN
# 10       Kai Kara-France         Brandon Moreno                     1
# 11        Viviane Araujo            Jessica Eye                     0
# 12        Oskar Piechota                    NaN                   NaN
# 13      Alistair Overeem  Jairzinho Rozenstruik                     0
# 14      Cynthia Calvillo       Marina Rodriguez                     1
# 15         Stefan Struve           Ben Rothwell                     1
# 16       Yana Kunitskaya             Aspen Ladd                     0
# 17           Song Yadong           Cody Stamann                     1
# 18           Ricky Simon               Rob Font                     1
# 19          Thiago Alves              Tim Means                     0
# 20         Jacob Kilburn                    NaN                   NaN
# 21           Matt Sayles         Bryce Mitchell                     0
# 22            Matt Wiman                    NaN                   NaN
# 23        Mallory Martin        Virna Jandiroba                     0
# 24          Trevor Smith                    NaN                   NaN
#
#    R_current_win_streak  ... B_win_by_Decision_Unanimous B_win_by_KO/TKO  \
# 0                     9  ...                           4               2
# 1                     6  ...                           4               8
# 2                     7  ...                           1               2
# 3                     4  ...                           6               4
# 4                     4  ...                           3               0
# 5                     2  ...                           0               4
# 6                     2  ...                           1               0
# 7                     0  ...                           1               0
# 8                     0  ...                           2               3
# 9                   NaN  ...                           0               0
# 10                    0  ...                           1               0
# 11                    3  ...                           0               0
# 12                  NaN  ...                           1               1
# 13                    0  ...                           2               6
# 14                    0  ...                           1               0
# 15                    0  ...                           1               5
# 16                    2  ...                           1               0
# 17                    0  ...                           0               1
# 18                    0  ...                           1               1
# 19                    1  ...                           5               7
# 20                  NaN  ...                         NaN             NaN
# 21                    1  ...                           0               0
# 22                  NaN  ...                           4               2
# 23                    0  ...                         NaN             NaN
# 24                  NaN  ...                           4               0
#
#    B_win_by_Submission B_win_by_TKO_Doctor_Stoppage B_wins  B_Stance  \
# 0                    2                            0      8  Orthodox
# 1                    2                            1     16  Orthodox
# 2                    0                            0      4  Orthodox
# 3                    0                            0     10  Orthodox
# 4                    6                            0      9  Orthodox
# 5                    0                            0      5  Orthodox
# 6                    1                            0      3  Orthodox
# 7                    0                            0      1  Orthodox
# 8                    3                            0      9  Orthodox
# 9                    0                            0      0  Orthodox
# 10                   0                            0      1  Orthodox
# 11                   0                            0      0  Orthodox
# 12                   0                            0      2  Southpaw
# 13                   0                            0      9  Orthodox
# 14                   3                            0      4  Orthodox
# 15                   5                            0     12  Orthodox
# 16                   0                            0      1  Orthodox
# 17                   1                            0      2  Orthodox
# 18                   0                            0      2  Orthodox
# 19                   1                            1     15  Orthodox
# 20                 NaN                          NaN    NaN       NaN
# 21                   0                            0      0  Orthodox
# 22                   3                            0      9  Orthodox
# 23                 NaN                          NaN    NaN       NaN
# 24                   0                            0      5  Orthodox
#
#    B_Height_cms B_Reach_cms B_Weight_lbs B_age
# 0        180.34      182.88          170    30
# 1        180.34      175.26          155    27
# 2        175.26      180.34          135    34
# 3        170.18       177.8          145    32
# 4        167.64      170.18          135    37
# 5         177.8      180.34          170    27
# 6        172.72      172.72          135    26
# 7        180.34      182.88          185    30
# 8        187.96      195.58          170    36
# 9         165.1      175.26          145    31
# 10        165.1      175.26          125    25
# 11       162.56      172.72          135    32
# 12       182.88      193.04          185    28
# 13       193.04       203.2          265    38
# 14       162.56      162.56          115    31
# 15       210.82      213.36          265    31
# 16       167.64      172.72          135    29
# 17       172.72      170.18          135    20
# 18       167.64      175.26          135    26
# 19       175.26       177.8          170    35
# 20          NaN         NaN          NaN   NaN
# 21       170.18      172.72          145    25
# 22        177.8      172.72          155    31
# 23          NaN         NaN          NaN   NaN
# 24        190.5       190.5          185    37
#
# [25 rows x 145 columns]

# %%
combined_template.to_csv('new_fights.csv')

# %%
combined_template = pd.read_csv('new_fights.csv')

# %%
combined_template.fillna(0, inplace=True)

# %%
method_dict = {
    'CNC': 'R_draw',
    'KO/TKO': 'R_win_by_KO/TKO',
    'KO/TKO  Elbow': 'R_win_by_KO/TKO',
    'KO/TKO  Elbows': 'R_win_by_KO/TKO',
    'KO/TKO  Kick': 'R_win_by_KO/TKO',
    'KO/TKO  Knee': 'R_win_by_KO/TKO',
    'KO/TKO  Punch': 'R_win_by_KO/TKO',
    'KO/TKO  Punches': 'R_win_by_KO/TKO',
    'KO/TKO  Spinning Back Fist': 'R_win_by_KO/TKO',
    'M-DEC': 'R_win_by_Decision_Majority',
    'S-DEC': 'R_win_by_Decision_Split',
    'SUB  Anaconda Choke': 'R_win_by_Submission',
    'SUB  Arm Triangle': 'R_win_by_Submission',
    'SUB  Armbar': 'R_win_by_Submission',
    'SUB  Guillotine Choke': 'R_win_by_Submission',
    'SUB  Other - Choke': 'R_win_by_Submission',
    'SUB  Other': 'R_win_by_Submission',
    'SUB  Peruvian Necktie': 'R_win_by_Submission',
    'SUB  Rear Naked Choke': 'R_win_by_Submission',
    'SUB  Triangle Choke': 'R_win_by_Submission',
    'U-DEC': 'R_win_by_Decision_Unanimous'
}

# %%
def calc_seconds(time):
    split_time = time.split(":", )
    return int(split_time[0])*60 + int(split_time[1])

# %%
#update relevant values for matches:
for row in np.arange(0,combined_template.shape[0])[::-1]:
    combined_template.R_current_win_streak[row] += 1
    combined_template.R_current_lose_streak[row] = 0
    combined_template.B_current_lose_streak[row] += 1
    combined_template.B_current_win_streak[row] = 0   
    combined_template.R_wins[row] += 1
    combined_template.R_total_rounds_fought[row] += combined_template.Round[row]
    combined_template.B_total_rounds_fought[row] += combined_template.Round[row]
    combined_template[method_dict[combined_template.Method[row]]][row] += 1 #additional win under the correct format
    combined_template['R_total_time_fought(seconds)'][row] += calc_seconds(combined_template.Time[row])    
    combined_template['B_total_time_fought(seconds)'][row] += calc_seconds(combined_template.Time[row])
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-22b330514472> in <module>
#       6     combined_template.B_current_win_streak[row] = 0
#       7     combined_template.R_wins[row] += 1
# ----> 8     combined_template.R_total_rounds_fought[row] += combined_template.Round[row]
#       9     combined_template.B_total_rounds_fought[row] += combined_template.Round[row]
#      10     combined_template[method_dict[combined_template.Method[row]]][row] += 1 #additional win under the correct format
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Round'

# %%
weight_class_dict = {
    'Bantamweight': "weight_class_Bantamweight",
    'Catch Weight': "weight_class_Catch Weight",
    'Featherweight': "weight_class_Featherweight",
    'Flyweight': "weight_class_Flyweight",
    'Heavyweight': "weight_class_Heavyweight",
    'Light Heavyweight': "weight_class_Light Heavyweight",
    'Lightweight': "weight_class_Lightweight",
    'Middleweight': "weight_class_Middleweight",
    'Open Weight': "weight_class_Open Weight",
    'Welterweight': "weight_class_Welterweight",
    "Women's Bantamweight": "weight_class_Women's Bantamweight",
    "Women's Featherweight": "weight_class_Women's Featherweight",
    "Women's Flyweight": "weight_class_Women's Flyweight",
    "Women's Strawweight": "weight_class_Women's Strawweight"   
}

weightcols = list(['Bantamweight',
 'Catch Weight',
 'Featherweight',
 'Flyweight',
 'Heavyweight',
 'Light Heavyweight',
 'Lightweight',
 'Middleweight',
 'Welterweight',
 "Women's Bantamweight",
 "Women's Featherweight",
 "Women's Flyweight",
 "Women's Strawweight"])

# %%
from sklearn.preprocessing import OneHotEncoder
weight_enc = OneHotEncoder()
weight_enc.fit(np.array(combined_template['Weight class']).reshape(-1,1))
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
a = weight_enc.transform(np.array(combined_template['Weight class']).reshape(-1,1))
weightdf = pd.DataFrame(a.toarray())
weight_cols = [weight_class_dict[weight] for weight in list(weight_enc.categories_[0])] #match columns with existing fight columns
weightdf.columns = weight_cols

# %%
combined_template['R_Stance'] = combined_template['R_Stance'].fillna("")
combined_template['B_Stance'] = combined_template['B_Stance'].fillna("")

stance_enc = OneHotEncoder()
stance_r = stance_enc.fit_transform(np.array(combined_template['R_Stance']).reshape(-1,1))
stance_b = stance_enc.fit_transform(np.array(combined_template['B_Stance']).reshape(-1,1))

# %%
stancedf_R = pd.DataFrame(stance_r.toarray())
stancedf_R.columns = list(['R_Stance_Orthodox', 'R_Stance_Southpaw', 'R_Stance_Switch'])
stancedf_R

stancedf_B = pd.DataFrame(stance_b.toarray())
stancedf_B.columns = list(['B_Stance_Orthodox'])
stancedf_B
# Out:
#     B_Stance_Orthodox
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# 5                 1.0
# 6                 1.0
# 7                 1.0
# 8                 1.0
# 9                 1.0
# 10                1.0
# 11                1.0
# 12                1.0
# 13                1.0
# 14                1.0
# 15                1.0
# 16                1.0

# %%
encoded_template = pd.concat([combined_template, weightdf], axis = 1)
encoded_template = pd.concat([encoded_template, stancedf_R, stancedf_B], axis = 1)

# %%
encoded_template.to_csv('new_encoded_template.csv')

# %%
encoded_template = pd.read_csv('new_encoded_template.csv')

# %%
test = pd.concat([encoded_template, processed_df], axis = 0, sort = False)

# %%
rearrange_cols = processed_df.columns #match columns in processed_df

# %%
test = pd.concat([encoded_template[rearrange_cols], processed_df], axis = 0, sort = True)

# %%
test = test[rearrange_cols]

# %%
test.to_csv('new_fights_final.csv')
