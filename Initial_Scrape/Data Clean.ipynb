# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime as dt
from datetime import timedelta
import json

# %% [markdown]
# # Data Load and Combine:

# %%
#Load Fighters:
fighters = pd.read_csv('../Data/fighter.csv', index_col = 0)
fighters.head(5)
fighters.reset_index(drop = True, inplace = True)

# %%
df = pd.read_csv('../Data/combined_fight_details.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['Fighter', 'KD', 'Sig. str. %', 'Td %', 'Sub. att', 'Pass', 'Rev.',
#        'Sig. str. Hits', 'Sig. str. Attempts', 'Total str. Hits',
#        'Total str. Attempts', 'Td Hits', 'Td Attempts', 'Head Hits',
#        'Head Attempts', 'Body Hits', 'Body Attempts', 'Leg Hits',
#        'Leg Attempts', 'Distance Hits', 'Distance Attempts', 'Clinch Hits',
#        'Clinch Attempts', 'Ground Hits', 'Ground Attempts', 'Fighter.1',
#        'KD.1', 'Sig. str. %.1', 'Td %.1', 'Sub. att.1', 'Pass.1', 'Rev..1',
#        'Sig. str. Hits.1', 'Sig. str. Attempts.1', 'Total str. Hits.1',
#        'Total str. Attempts.1', 'Td Hits.1', 'Td Attempts.1', 'Head Hits.1',
#        'Head Attempts.1', 'Body Hits.1', 'Body Attempts.1', 'Leg Hits.1',
#        'Leg Attempts.1', 'Distance Hits.1', 'Distance Attempts.1',
#        'Clinch Hits.1', 'Clinch Attempts.1', 'Ground Hits.1',
#        'Ground Attempts.1', 'rounds', 'time', 'format', 'referee', 'url'],
#       dtype='object')

# %% [markdown]
# df at this point is a pandas DataFrame. Each observation is an individual fight with both fighters' statistics for that particular fight

# %% [markdown]
# # Clean Event Details Data:

# %% [markdown]
# ### Find Null Values:

# %%
drop_index = df[df['Fighter'] == '99999'].index
df.drop(drop_index, axis = 0, inplace = True)

# %% [markdown]
# ### Change Data Formats:

# %%
df.dtypes
# Out:
# Fighter                  object
# KD                        int64
# Sig. str. %              object
# Td %                     object
# Sub. att                  int64
# Pass                      int64
# Rev.                      int64
# Sig. str. Hits            int64
# Sig. str. Attempts        int64
# Total str. Hits           int64
# Total str. Attempts       int64
# Td Hits                   int64
# Td Attempts               int64
# Head Hits                 int64
# Head Attempts             int64
# Body Hits                 int64
# Body Attempts             int64
# Leg Hits                  int64
# Leg Attempts              int64
# Distance Hits             int64
# Distance Attempts         int64
# Clinch Hits               int64
# Clinch Attempts           int64
# Ground Hits               int64
# Ground Attempts           int64
# Fighter.1                object
# KD.1                      int64
# Sig. str. %.1            object
# Td %.1                   object
# Sub. att.1                int64
# Pass.1                    int64
# Rev..1                    int64
# Sig. str. Hits.1          int64
# Sig. str. Attempts.1      int64
# Total str. Hits.1         int64
# Total str. Attempts.1     int64
# Td Hits.1                 int64
# Td Attempts.1             int64
# Head Hits.1               int64
# Head Attempts.1           int64
# Body Hits.1               int64
# Body Attempts.1           int64
# Leg Hits.1                int64
# Leg Attempts.1            int64
# Distance Hits.1           int64
# Distance Attempts.1       int64
# Clinch Hits.1             int64
# Clinch Attempts.1         int64
# Ground Hits.1             int64
# Ground Attempts.1         int64
# rounds                    int64
# time                     object
# format                   object
# referee                  object
# url                      object
# dtype: object

# %%
df.columns
# Out:
# Index(['Fighter', 'KD', 'Sig. str. %', 'Td %', 'Sub. att', 'Pass', 'Rev.',
#        'Sig. str. Hits', 'Sig. str. Attempts', 'Total str. Hits',
#        'Total str. Attempts', 'Td Hits', 'Td Attempts', 'Head Hits',
#        'Head Attempts', 'Body Hits', 'Body Attempts', 'Leg Hits',
#        'Leg Attempts', 'Distance Hits', 'Distance Attempts', 'Clinch Hits',
#        'Clinch Attempts', 'Ground Hits', 'Ground Attempts', 'Fighter.1',
#        'KD.1', 'Sig. str. %.1', 'Td %.1', 'Sub. att.1', 'Pass.1', 'Rev..1',
#        'Sig. str. Hits.1', 'Sig. str. Attempts.1', 'Total str. Hits.1',
#        'Total str. Attempts.1', 'Td Hits.1', 'Td Attempts.1', 'Head Hits.1',
#        'Head Attempts.1', 'Body Hits.1', 'Body Attempts.1', 'Leg Hits.1',
#        'Leg Attempts.1', 'Distance Hits.1', 'Distance Attempts.1',
#        'Clinch Hits.1', 'Clinch Attempts.1', 'Ground Hits.1',
#        'Ground Attempts.1', 'rounds', 'time', 'format', 'referee', 'url'],
#       dtype='object')

# %% [markdown]
# Convert %'s into floats:

# %%
df['Sig. str. %'] = df['Sig. str. %'].apply(lambda x: re.sub('%', '', x))
df['Td %'] = df['Td %'].apply(lambda x: re.sub('%', '', x))

df['Sig. str. %.1'] = df['Sig. str. %.1'].apply(lambda x: re.sub('%', '', x))
df['Td %.1'] = df['Td %.1'].apply(lambda x: re.sub('%', '', x))

# %%
df['Sig. str. %'] = df['Sig. str. %'].astype(float)
df['Sig. str. %'] = df['Sig. str. %'] / 100

df['Td %'] = df['Td %'].astype(float)
df['Td %'] = df['Td %'] / 100

df['Sig. str. %.1'] = df['Sig. str. %.1'].astype(float)
df['Sig. str. %.1'] = df['Sig. str. %.1'] / 100

df['Td %.1'] = df['Td %.1'].astype(float)
df['Td %.1'] = df['Td %.1'] / 100

# %% [markdown]
# # Combine with main_event:

# %%
event_data = pd.read_csv('../Data/event_level_data.csv', index_col = 0) 
event_data.drop(drop_index, axis = 0, inplace = True)

# %%
combined_df = pd.concat([event_data, df], axis = 1)
combined_df.head(5)
# Out:
#   Winner           R_fighter       B_fighter  R_STR  B_STR  R_TD  B_TD  R_SUB  \
# 0    win    Charles Oliveira       Kevin Lee     43     41     0     2      2
# 1    win       Gilbert Burns     Demian Maia     13      4     0     2      0
# 2    win      Renato Moicano  Damir Hadzovic      1      1     1     0      1
# 3    win       Nikita Krylov   Johnny Walker     45     37     3     0      0
# 4    win  Francisco Trinaldo   John Makdessi     55     67     0     0      0
#
#    B_SUB  R_PASS  ...  Distance Attempts.1 Clinch Hits.1 Clinch Attempts.1  \
# 0      0       0  ...                   56             2                 2
# 1      0       0  ...                    7             0                 0
# 2      0       1  ...                    5             0                 0
# 3      0       4  ...                   18             2                 3
# 4      0       0  ...                  121             2                 2
#
#   Ground Hits.1  Ground Attempts.1 rounds      time             format  \
# 0             6                  7      3  00:00:28  5 Rnd (5-5-5-5-5)
# 1             8                  9      1  00:02:34      3 Rnd (5-5-5)
# 2             0                  0      1  00:00:44      3 Rnd (5-5-5)
# 3            33                 37      3  00:05:00      3 Rnd (5-5-5)
# 4             0                  0      3  00:05:00      3 Rnd (5-5-5)
#
#          referee                                                url
# 0   Mike Beltran  http://ufcstats.com/fight-details/e0b323dae5bf...
# 1    Osiris Maia  http://ufcstats.com/fight-details/e0b323dae5bf...
# 2  Eduardo Herdy  http://ufcstats.com/fight-details/e0b323dae5bf...
# 3   Mike Beltran  http://ufcstats.com/fight-details/e0b323dae5bf...
# 4    Osiris Maia  http://ufcstats.com/fight-details/e0b323dae5bf...
#
# [5 rows x 76 columns]

# %%
print(combined_df.isna().any())
sum(combined_df.isna().any())
#Null values exist for stance, stance.1 and referee
# Out:
# Winner                   False
# R_fighter                False
# B_fighter                False
# R_STR                    False
# B_STR                    False
# R_TD                     False
# B_TD                     False
# R_SUB                    False
# B_SUB                    False
# R_PASS                   False
# B_PASS                   False
# WEIGHT_CLASS             False
# METHOD                   False
# DETAIL                    True
# ROUND                    False
# TIME                     False
# title_bout               False
# link                     False
# date                     False
# location                 False
# attendance                True
# Fighter                  False
# KD                       False
# Sig. str. %              False
# Td %                     False
# Sub. att                 False
# Pass                     False
# Rev.                     False
# Sig. str. Hits           False
# Sig. str. Attempts       False
# Total str. Hits          False
# Total str. Attempts      False
# Td Hits                  False
# Td Attempts              False
# Head Hits                False
# Head Attempts            False
# Body Hits                False
# Body Attempts            False
# Leg Hits                 False
# Leg Attempts             False
# Distance Hits            False
# Distance Attempts        False
# Clinch Hits              False
# Clinch Attempts          False
# Ground Hits              False
# Ground Attempts          False
# Fighter.1                False
# KD.1                     False
# Sig. str. %.1            False
# Td %.1                   False
# Sub. att.1               False
# Pass.1                   False
# Rev..1                   False
# Sig. str. Hits.1         False
# Sig. str. Attempts.1     False
# Total str. Hits.1        False
# Total str. Attempts.1    False
# Td Hits.1                False
# Td Attempts.1            False
# Head Hits.1              False
# Head Attempts.1          False
# Body Hits.1              False
# Body Attempts.1          False
# Leg Hits.1               False
# Leg Attempts.1           False
# Distance Hits.1          False
# Distance Attempts.1      False
# Clinch Hits.1            False
# Clinch Attempts.1        False
# Ground Hits.1            False
# Ground Attempts.1        False
# rounds                   False
# time                     False
# format                   False
# referee                   True
# url                      False
# dtype: bool
# 3

# %%
combined_df.columns
# Out:
# Index(['Winner', 'R_fighter', 'B_fighter', 'R_STR', 'B_STR', 'R_TD', 'B_TD',
#        'R_SUB', 'B_SUB', 'R_PASS', 'B_PASS', 'WEIGHT_CLASS', 'METHOD',
#        'DETAIL', 'ROUND', 'TIME', 'title_bout', 'link', 'date', 'location',
#        'attendance', 'Fighter', 'KD', 'Sig. str. %', 'Td %', 'Sub. att',
#        'Pass', 'Rev.', 'Sig. str. Hits', 'Sig. str. Attempts',
#        'Total str. Hits', 'Total str. Attempts', 'Td Hits', 'Td Attempts',
#        'Head Hits', 'Head Attempts', 'Body Hits', 'Body Attempts', 'Leg Hits',
#        'Leg Attempts', 'Distance Hits', 'Distance Attempts', 'Clinch Hits',
#        'Clinch Attempts', 'Ground Hits', 'Ground Attempts', 'Fighter.1',
#        'KD.1', 'Sig. str. %.1', 'Td %.1', 'Sub. att.1', 'Pass.1', 'Rev..1',
#        'Sig. str. Hits.1', 'Sig. str. Attempts.1', 'Total str. Hits.1',
#        'Total str. Attempts.1', 'Td Hits.1', 'Td Attempts.1', 'Head Hits.1',
#        'Head Attempts.1', 'Body Hits.1', 'Body Attempts.1', 'Leg Hits.1',
#        'Leg Attempts.1', 'Distance Hits.1', 'Distance Attempts.1',
#        'Clinch Hits.1', 'Clinch Attempts.1', 'Ground Hits.1',
#        'Ground Attempts.1', 'rounds', 'time', 'format', 'referee', 'url'],
#       dtype='object')

# %%
#Drop redundant data:
drop_columns = ['R_STR', 'B_STR', 'R_TD', 'B_TD',
       'R_SUB', 'B_SUB', 'R_PASS', 'B_PASS', 'ROUND', 'TIME', 'link']              
combined_df.drop(drop_columns, axis = 1, inplace = True)

# %% [markdown]
# # Feature Engineering:

# %% [markdown]
# ### Winner of fight (ML label):

# %%
winner = []
for index, row in combined_df.iterrows():
    
    if row['Winner'] != 'win':
        winner.append(99999)
    
    elif (row['R_fighter'] == row['Fighter']):
        winner.append(0)
    else:
        winner.append(1)

# %%
combined_df['label'] = winner

# %%
combined_df.head(5)
# Out:
#   Winner           R_fighter       B_fighter       WEIGHT_CLASS  METHOD  \
# 0    win    Charles Oliveira       Kevin Lee        Lightweight     SUB
# 1    win       Gilbert Burns     Demian Maia       Welterweight  KO/TKO
# 2    win      Renato Moicano  Damir Hadzovic        Lightweight     SUB
# 3    win       Nikita Krylov   Johnny Walker  Light Heavyweight   U-DEC
# 4    win  Francisco Trinaldo   John Makdessi        Lightweight   U-DEC
#
#              DETAIL  title_bout        date  \
# 0  Guillotine Choke         0.0  14-03-2020
# 1             Punch         0.0  14-03-2020
# 2  Rear Naked Choke         0.0  14-03-2020
# 3               NaN         0.0  14-03-2020
# 4               NaN         0.0  14-03-2020
#
#                              location  attendance  ... Clinch Hits.1  \
# 0  Brasilia, Distrito Federal, Brazil         0.0  ...             2
# 1  Brasilia, Distrito Federal, Brazil         0.0  ...             0
# 2  Brasilia, Distrito Federal, Brazil         0.0  ...             0
# 3  Brasilia, Distrito Federal, Brazil         0.0  ...             2
# 4  Brasilia, Distrito Federal, Brazil         0.0  ...             2
#
#    Clinch Attempts.1  Ground Hits.1  Ground Attempts.1  rounds      time  \
# 0                  2              6                  7       3  00:00:28
# 1                  0              8                  9       1  00:02:34
# 2                  0              0                  0       1  00:00:44
# 3                  3             33                 37       3  00:05:00
# 4                  2              0                  0       3  00:05:00
#
#               format        referee  \
# 0  5 Rnd (5-5-5-5-5)   Mike Beltran
# 1      3 Rnd (5-5-5)    Osiris Maia
# 2      3 Rnd (5-5-5)  Eduardo Herdy
# 3      3 Rnd (5-5-5)   Mike Beltran
# 4      3 Rnd (5-5-5)    Osiris Maia
#
#                                                  url  label
# 0  http://ufcstats.com/fight-details/e0b323dae5bf...      1
# 1  http://ufcstats.com/fight-details/e0b323dae5bf...      1
# 2  http://ufcstats.com/fight-details/e0b323dae5bf...      0
# 3  http://ufcstats.com/fight-details/e0b323dae5bf...      1
# 4  http://ufcstats.com/fight-details/e0b323dae5bf...      0
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Match Time:

# %%
#Reformat match format:

round_times = combined_df['format'].apply(lambda x: re.search(r'\(.*\)', x))
round_times = round_times.apply(lambda x: x.group().strip('()').split('-') if x != None else [1])
round_times = round_times.apply(lambda x: np.array(x, dtype = 'float'))
round_times[0:5]
# Out:
# 0    [5.0, 5.0, 5.0, 5.0, 5.0]
# 1              [5.0, 5.0, 5.0]
# 2              [5.0, 5.0, 5.0]
# 3              [5.0, 5.0, 5.0]
# 4              [5.0, 5.0, 5.0]
# Name: format, dtype: object

# %%
#Returns time in minutes given datetime object:
def to_minutes(time):
    
    set_time = dt.strptime(time, '%H:%M:%S')
    
    return set_time.minute + set_time.second / 60

# %%
#Calculate total match time
round_dot = []

for num_rounds, time, item in zip(combined_df['rounds'], combined_df['time'], round_times):
    
    minutes = to_minutes(time)
    
    round_indicator = np.zeros(len(item))
    round_indicator[0: num_rounds-1] = 1
    
    round_time = round(np.dot(round_indicator, item) + minutes, 2)
    
    round_dot.append(round_time)

# %%
combined_df['match_time'] = round_dot

# %%
combined_df.reset_index(drop = True, inplace = True)
combined_df
# Out:
#      Winner           R_fighter       B_fighter       WEIGHT_CLASS  METHOD  \
# 0       win    Charles Oliveira       Kevin Lee        Lightweight     SUB
# 1       win       Gilbert Burns     Demian Maia       Welterweight  KO/TKO
# 2       win      Renato Moicano  Damir Hadzovic        Lightweight     SUB
# 3       win       Nikita Krylov   Johnny Walker  Light Heavyweight   U-DEC
# 4       win  Francisco Trinaldo   John Makdessi        Lightweight   U-DEC
# ...     ...                 ...             ...                ...     ...
# 5538    win      Gerard Gordeau    Kevin Rosier        Open Weight  KO/TKO
# 5539    win        Ken Shamrock   Patrick Smith        Open Weight     SUB
# 5540    win        Royce Gracie   Art Jimmerson        Open Weight     SUB
# 5541    win        Kevin Rosier    Zane Frazier        Open Weight  KO/TKO
# 5542    win      Gerard Gordeau      Teila Tuli        Open Weight  KO/TKO
#
#                 DETAIL  title_bout        date  \
# 0     Guillotine Choke         0.0  14-03-2020
# 1                Punch         0.0  14-03-2020
# 2     Rear Naked Choke         0.0  14-03-2020
# 3                  NaN         0.0  14-03-2020
# 4                  NaN         0.0  14-03-2020
# ...                ...         ...         ...
# 5538               NaN         0.0  12-11-1993
# 5539         Heel Hook         0.0  12-11-1993
# 5540             Other         0.0  12-11-1993
# 5541               NaN         0.0  12-11-1993
# 5542              Kick         0.0  12-11-1993
#
#                                 location  attendance  ... Clinch Attempts.1  \
# 0     Brasilia, Distrito Federal, Brazil         0.0  ...                 2
# 1     Brasilia, Distrito Federal, Brazil         0.0  ...                 0
# 2     Brasilia, Distrito Federal, Brazil         0.0  ...                 0
# 3     Brasilia, Distrito Federal, Brazil         0.0  ...                 3
# 4     Brasilia, Distrito Federal, Brazil         0.0  ...                 2
# ...                                  ...         ...  ...               ...
# 5538               Denver, Colorado, USA      2800.0  ...                 0
# 5539               Denver, Colorado, USA      2800.0  ...                 1
# 5540               Denver, Colorado, USA      2800.0  ...                 0
# 5541               Denver, Colorado, USA      2800.0  ...                19
# 5542               Denver, Colorado, USA      2800.0  ...                 0
#
#       Ground Hits.1  Ground Attempts.1  rounds      time             format  \
# 0                 6                  7       3  00:00:28  5 Rnd (5-5-5-5-5)
# 1                 8                  9       1  00:02:34      3 Rnd (5-5-5)
# 2                 0                  0       1  00:00:44      3 Rnd (5-5-5)
# 3                33                 37       3  00:05:00      3 Rnd (5-5-5)
# 4                 0                  0       3  00:05:00      3 Rnd (5-5-5)
# ...             ...                ...     ...       ...                ...
# 5538              0                  0       1  00:00:59      No Time Limit
# 5539              2                  6       1  00:01:49      No Time Limit
# 5540              0                  0       1  00:02:18      No Time Limit
# 5541              2                  2       1  00:04:20      No Time Limit
# 5542              0                  0       1  00:00:26      No Time Limit
#
#                    referee                                                url  \
# 0             Mike Beltran  http://ufcstats.com/fight-details/e0b323dae5bf...
# 1              Osiris Maia  http://ufcstats.com/fight-details/e0b323dae5bf...
# 2            Eduardo Herdy  http://ufcstats.com/fight-details/e0b323dae5bf...
# 3             Mike Beltran  http://ufcstats.com/fight-details/e0b323dae5bf...
# 4              Osiris Maia  http://ufcstats.com/fight-details/e0b323dae5bf...
# ...                    ...                                                ...
# 5538  Joao Alberto Barreto  http://ufcstats.com/fight-details/ac7ca2ec38b9...
# 5539  Joao Alberto Barreto  http://ufcstats.com/fight-details/46acd54cc0c9...
# 5540  Joao Alberto Barreto  http://ufcstats.com/fight-details/cecdc0da5842...
# 5541  Joao Alberto Barreto  http://ufcstats.com/fight-details/2d2bbc86e941...
# 5542  Joao Alberto Barreto  http://ufcstats.com/fight-details/567a09fd200c...
#
#       label  match_time
# 0         1       10.47
# 1         1        2.57
# 2         0        0.73
# 3         1       15.00
# 4         0       15.00
# ...     ...         ...
# 5538      0        0.98
# 5539      0        1.82
# 5540      0        2.30
# 5541      0        4.33
# 5542      0        0.43
#
# [5543 rows x 67 columns]

# %% [markdown]
# # Combine Fighter Information:

# %%
player_columns = ['DOB', 'Height', 'Reach', 'Stance', 'Weight',
                 'DOB.1', 'Height.1', 'Reach.1', 'Stance.1', 'Weight.1',]

# %%
R_B_combined = pd.DataFrame()

#Given 2 players in a match, retrieve their corresponding personal attributes (height, weight, reach, etc.)

for index, row in combined_df.iterrows():
    
    R_fighter = row['Fighter']
    B_fighter = row['Fighter.1']
    
    R_stats = fighters[fighters['Name'] == R_fighter].copy()
    B_stats = fighters[fighters['Name'] == B_fighter].copy()
    
    R_stats.reset_index(drop = True, inplace = True)
    B_stats.reset_index(drop = True, inplace = True)
    
    combined = pd.concat([R_stats, B_stats], axis = 1)
    R_B_combined = pd.concat([R_B_combined, combined], axis = 0)

# %%
R_B_combined.drop('Name', axis = 1, inplace = True)
R_B_combined.columns = player_columns
R_B_combined.reset_index(drop = True, inplace = True)

# %%
data = pd.concat([combined_df, R_B_combined], axis = 1)
data.shape
# Out:
# (5543, 77)

# %%
data.to_csv('../Data/fights.csv')

# %% [markdown]
# # Navigating the Data:

# %%
df = pd.read_csv('../Data/fights.csv', index_col = 0)
print(df.shape)
df.head(5)
# Out:
# (5543, 77)
#   Winner           R_fighter       B_fighter       WEIGHT_CLASS  METHOD  \
# 0    win    Charles Oliveira       Kevin Lee        Lightweight     SUB
# 1    win       Gilbert Burns     Demian Maia       Welterweight  KO/TKO
# 2    win      Renato Moicano  Damir Hadzovic        Lightweight     SUB
# 3    win       Nikita Krylov   Johnny Walker  Light Heavyweight   U-DEC
# 4    win  Francisco Trinaldo   John Makdessi        Lightweight   U-DEC
#
#              DETAIL  title_bout        date  \
# 0  Guillotine Choke         0.0  14-03-2020
# 1             Punch         0.0  14-03-2020
# 2  Rear Naked Choke         0.0  14-03-2020
# 3               NaN         0.0  14-03-2020
# 4               NaN         0.0  14-03-2020
#
#                              location  attendance  ...         DOB  Height  \
# 0  Brasilia, Distrito Federal, Brazil         0.0  ...  04-09-1992      69
# 1  Brasilia, Distrito Federal, Brazil         0.0  ...  06-11-1977      73
# 2  Brasilia, Distrito Federal, Brazil         0.0  ...  21-05-1989      61
# 3  Brasilia, Distrito Federal, Brazil         0.0  ...  30-03-1992      78
# 4  Brasilia, Distrito Federal, Brazil         0.0  ...  24-08-1978      69
#
#    Reach     Stance  Weight       DOB.1  Height.1  Reach.1   Stance.1  \
# 0     77   Orthodox     170  17-10-1989        61       74   Orthodox
# 1     72   Southpaw     170  20-07-1986        61       71   Orthodox
# 2     72   Orthodox     155  08-08-1986        69       70   Orthodox
# 3     82   Orthodox     205  07-03-1992        75       77   Orthodox
# 4     70   Southpaw     155  03-05-1985        68       68   Orthodox
#
#    Weight.1
# 0       155
# 1       170
# 2       155
# 3       205
# 4       155
#
# [5 rows x 77 columns]

# %%
#Relevant columns when breaking out data for specific fighters

fight_columns = ['Winner', 'R_fighter', 'Fighter', 'KD',
       'Sig. str. %', 'Td %', 'Sub. att', 'Pass', 'Rev.', 'Sig. str. Hits',
       'Sig. str. Attempts', 'Total str. Hits', 'Total str. Attempts',
       'Td Hits', 'Td Attempts', 'Head Hits', 'Head Attempts', 'Body Hits',
       'Body Attempts', 'Leg Hits', 'Leg Attempts', 'Distance Hits',
       'Distance Attempts', 'Clinch Hits', 'Clinch Attempts', 'Ground Hits',
       'Ground Attempts', 'DOB', 'Height', 'Reach',
       'Stance', 'Weight', 'date', 'match_time']

fight_columns_1 = ['Winner','R_fighter','Fighter.1', 'KD.1', 'Sig. str. %.1', 'Td %.1',
       'Sub. att.1', 'Pass.1', 'Rev..1', 'Sig. str. Hits.1',
       'Sig. str. Attempts.1', 'Total str. Hits.1', 'Total str. Attempts.1',
       'Td Hits.1', 'Td Attempts.1', 'Head Hits.1', 'Head Attempts.1',
       'Body Hits.1', 'Body Attempts.1', 'Leg Hits.1', 'Leg Attempts.1',
       'Distance Hits.1', 'Distance Attempts.1', 'Clinch Hits.1',
       'Clinch Attempts.1', 'Ground Hits.1', 'Ground Attempts.1', 'DOB.1', 'Height.1', 'Reach.1', 'Stance.1',
       'Weight.1', 'date', 'match_time']

# %%
def get_fight_attributes(index):
    
    temp = df.loc[index]
    return temp[['Fighter', 'Fighter.1', 'title_bout',
                'date', 'location', 'attendance', 'rounds', 'time', 'format', 'referee']]
    

def get_fights(fighter):
    
    data = df[(df['Fighter'] == fighter) | (df['Fighter.1'] == fighter)]
    
    return data


#get_personal returns fight statistics only fighter  
def get_personal(fights, fighter):
    
    a = fights[fights['Fighter'] == fighter]
    a1 = fights[fights['Fighter.1'] == fighter]
    
    a = a[fight_columns].copy()
    a1 = a1[fight_columns_1].copy()

    a1.columns = fight_columns  
    
    combined = pd.concat([a, a1], axis = 0)
    combined.sort_index(ascending = False, inplace = True)
    
    return combined

# %% [markdown]
# A "personal" is a pandas DataFrame (1 per fighter). This dataframe consists of every fight the fighter has participated in with relevant statistics and physical attribute detail.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# The purpose of these functions is to determine cumulative values up to (but not including) the current match, given a fighter's personal_df. The shift attribute for the following functions indicates this shift of excluding the current fight's data from the fighter's cumulative stats.
#
# When predicting new fights, we will simply set shift to False in order to aggregate all a fighter's prior statistics

# %%
#Calculate age of fighter given DOB:
def calc_age(personal):
    try:
        dob = dt.strptime(personal['DOB'].iloc[0], '%d-%m-%Y')
        match_dates = personal['date'].apply(lambda x: dt.strptime(x, '%d-%m-%Y'))

        ages = match_dates.apply(lambda x: round(((x - dob).days)/365,2))
    except:
        ages = pd.Series(float(0.0), index=personal.index)
        
    ages = ages.rename('age')

    return ages

# %%
#Calculate a fighter's # of Wins & Losses:
def calc_WL(personal, shift = True):
        
    wins = personal['R_fighter'].apply(lambda x: x == personal['Fighter'].iloc[0])
    losses = personal['R_fighter'].apply(lambda x: x != personal['Fighter'].iloc[0])
    draws = pd.Series(0, index = wins.index)
    
    for idx in wins.index:
        if personal['Winner'].loc[idx] != 'win':
            draws[idx] = 1
            wins[idx] = False
            losses[idx] = False
    
    #Winning/Losing Streak Algorith:
    switch = []
    for item in np.arange(1, len(wins)):
        if wins.iloc[item] == wins.iloc[item-1]:
            switch.append(False)
        else:
            switch.append(True)
    
    if wins.iloc[0]:
        streak = [1]
    else:
        streak = [-1]

    for item, swap in zip(wins, switch):
        if swap:
            streak.append(1 * -np.sign(streak[-1]))
        else:
            streak.append(streak[-1] + np.sign(streak[-1])*1)

            
    streak = pd.Series(streak, index = wins.index)
    #End streak algorithm
        
    
    wl = pd.DataFrame([np.cumsum(losses), np.cumsum(wins), np.cumsum(draws)]).T
    wl = pd.concat([wl, streak], axis = 1)
    wl.columns = ['loss', 'win', 'draws', 'streak']
    
    if shift:
        wl = wl.shift(1)
    
    wl.iloc[0, :] = 0

    return wl

# %%
#Calculate a fighter's cumulative time in the ring (across all matches):
def calc_time(personal, shift = True):

    time = np.cumsum(personal['match_time'])
    initial = time.iloc[0]
    
    if shift:
        time = time.shift(1)
    
    time.iloc[0] = initial
    time = time.rename('cum_match_time')

    return time

# %%
#Calculate cumulative fight statistics for each fighter
def calc_stats(personal, shift = True):
    stat_columns = ['KD', 'Sub. att', 'Pass',
       'Rev.', 'Sig. str. Hits', 'Sig. str. Attempts', 'Total str. Hits',
       'Total str. Attempts', 'Td Hits', 'Td Attempts', 'Head Hits',
       'Head Attempts', 'Body Hits', 'Body Attempts', 'Leg Hits',
       'Leg Attempts', 'Distance Hits', 'Distance Attempts', 'Clinch Hits',
       'Clinch Attempts', 'Ground Hits', 'Ground Attempts']
    
    stats = personal[stat_columns]
    
    cumulative_columns = ['cum_{}'.format(item) for item in stat_columns]
    
    stats = np.cumsum(stats)
    initial = stats.iloc[0, :].copy()
    
    if shift:
        stats = stats.shift(1)
    
    stats.iloc[0, :] = initial
    stats.columns = cumulative_columns
    
    return stats

# %%
#The calculated personal is the personal_df with all cumulative statistics included

def get_calculated_personal(fighter, shift = True):
    
    if (len(df[df['Fighter'] == fighter]) == 0) & (len(df[df['Fighter.1'] == fighter]) == 0):
        return None
    
    
    personal = get_personal(df, fighter)
    
    ages = calc_age(personal)
    
    wl = calc_WL(personal, shift)
    round_times = calc_time(personal, shift)
    stats = calc_stats(personal, shift)
    
    final = pd.concat([personal, ages, wl, round_times, stats], axis = 1)
    
    return final

# %%
test_personal = get_personal(df, 'Dustin Poirier')
len(test_personal)
calc_WL(test_personal)
# Out:
#       loss   win  draws  streak
# 4033   0.0   0.0    0.0     0.0
# 3922   0.0   1.0    0.0     1.0
# 3784   0.0   2.0    0.0     2.0
# 3702   0.0   3.0    0.0     3.0
# 3617   0.0   4.0    0.0     4.0
# 3412   1.0   4.0    0.0    -1.0
# 3353   1.0   5.0    0.0     1.0
# 3153   2.0   5.0    0.0    -1.0
# 3015   2.0   6.0    0.0     1.0
# 2885   2.0   7.0    0.0     2.0
# 2634   2.0   8.0    0.0     3.0
# 2401   3.0   8.0    0.0    -1.0
# 2304   3.0   9.0    0.0     1.0
# 2032   3.0  10.0    0.0     2.0
# 1853   3.0  11.0    0.0     3.0
# 1699   3.0  12.0    0.0     4.0
# 1500   4.0  12.0    0.0    -1.0
# 1405   4.0  13.0    0.0     1.0
# 1168   4.0  13.0    1.0    -1.0
# 959    4.0  14.0    1.0     1.0
# 811    4.0  15.0    1.0     2.0
# 474    4.0  16.0    1.0     3.0
# 256    4.0  17.0    1.0     4.0

# %%
get_calculated_personal('Davi Ramos')
# Out:
#      Winner        R_fighter     Fighter  KD  Sig. str. %  Td %  Sub. att  \
# 1469    win    Sergio Moraes  Davi Ramos   0         0.28  0.00         0
# 1117    win       Davi Ramos  Davi Ramos   0         0.44  0.55         1
# 942     win       Davi Ramos  Davi Ramos   0         0.50  1.00         1
# 706     win       Davi Ramos  Davi Ramos   0         0.80  1.00         1
# 418     win       Davi Ramos  Davi Ramos   0         0.55  0.42         0
# 258     win  Islam Makhachev  Davi Ramos   0         0.12  0.00         0
#
#       Pass  Rev.  Sig. str. Hits  ...  cum_Body Hits  cum_Body Attempts  \
# 1469     0     0              35  ...            7.0               17.0
# 1117     5     0              55  ...            7.0               17.0
# 942      2     0               6  ...           11.0               22.0
# 706      2     0               4  ...           12.0               25.0
# 418      3     0              63  ...           13.0               26.0
# 258      0     0               7  ...           20.0               41.0
#
#       cum_Leg Hits  cum_Leg Attempts  cum_Distance Hits  \
# 1469           7.0               8.0               35.0
# 1117           7.0               8.0               35.0
# 942            9.0              10.0               79.0
# 706            9.0              10.0               84.0
# 418            9.0              10.0               84.0
# 258           21.0              23.0              125.0
#
#       cum_Distance Attempts  cum_Clinch Hits  cum_Clinch Attempts  \
# 1469                  122.0              0.0                  0.0
# 1117                  122.0              0.0                  0.0
# 942                   227.0              9.0                 13.0
# 706                   238.0              9.0                 13.0
# 418                   239.0              9.0                 13.0
# 258                   331.0             14.0                 18.0
#
#       cum_Ground Hits  cum_Ground Attempts
# 1469              0.0                  0.0
# 1117              0.0                  0.0
# 942               2.0                  6.0
# 706               3.0                  7.0
# 418               7.0                 11.0
# 258              24.0                 28.0
#
# [6 rows x 62 columns]

# %%
test = test_personal

# %% [markdown]
# # Generate the Personals:

# %%
#personal_dict: key = name, values = personal_dfs with cumulative statistics

personal_dict = {}

for name in fighters.Name:
    print(name)
    personal_dict[name] = get_calculated_personal(name)
# Out:
# Gabriel Silva
# Aalon Cruz
# Davi Ramos
# Sean McCorkle
# Glaico Franca
# Dylan Andrews
# Luke Rockhold
# John Salter
# Joe Brammer
# Gina Mazany
# Rachael Ostovich
# Chase Sherman
# Benji Radach
# Caros Fodor
# Koji Oishi
# Josh Bryant
# Henry Briones
# Jason Reinhardt
# Darko Stosic
# Sean Sherk
# Abubakar Nurmagomedov
# Dustin Poirier
# Rudyard Moncayo
# Kevin Jordan
# Artem Lobov
# Trent Jenkins
# Kerry Schall
# Khabib Nurmagomedov
# Pete Sell
# Bas Rutten
# John Cholish
# Walt Harris
# Nate Schroeder
# Arnold Allen
# Jack Marshman
# Marcus Aurelio
# Matt Horwich
# Oluwale Bamgbose
# Nate Mohr
# Tanner Boser
# Jorge Gurgel
# Gerald Strebendt
# Chase Gormley
# Rob Font
# Houston Alexander
# Rob Kimmons
# Costas Philippou
# Henry Cejudo
# Jon Olav Einemo
# Marvin Eastman
# Dale Hartt
# Chris Price
# Kailin Curran
# Andrea Lee
# Mike Jackson
# Cain Carrizosa
# Devin Powell
# Scott Askham
# Maurice Greene
# Branden Lee Hinkle
# Ed Herman
# Charles Oliveira
# Milana Dudieva
# Tarec Saffiedine
# Joey Gomez
# Paul Varelans
# Rogerio Bontorin
# Jon Jones
# Volkan Oezdemir
# Tommy Hayden
# Dave Galera
# Rafael Carino
# Kimo Leopoldo
# Beneil Dariush
# Myles Jury
# Anthony Hernandez
# Johny Hendricks
# David Velasquez
# Diego Rivas
# Jack Hermansson
# Adam Yandiev
# Mark Hominick
# Randy Couture
# Ben Askren
# Steve Steinbeiss
# Scott Jorgensen
# Matt Bessette
# Fabiano Scherner
# Tom DeBlass
# Caio Magalhaes
# Jimmy Wallhead
# Brad Tavares
# Marcelo Guimaraes
# Fredy Serrano
# Enson Inoue
# Jon Delos Reyes
# Rocky Lee
# Sean Pierson
# Sheymon Moraes
# Michal Oleksiejczuk
# Sean Strickland
# Shamil Gamzatov
# Dieusel Berto
# Rafael Natal
# Matt Lindland
# Magnus Cedenblad
# Chris Liguori
# Sam Adkins
# Scott Fiedler
# Vitor Belfort
# Joao Roque
# Yuri Villefort
# Said Nurmagomedov
# Cain Velasquez
# Emil Meek
# Joey Gambino
# Shunichi Shimizu
# Igor Zinoviev
# Nikita Krylov
# Dominick Cruz
# Davey Grant
# Aaron Rosa
# Samy Schiavo
# Mario Neto
# Shana Dobson
# Vernon White
# Julio Arce
# Garett Whiteley
# Jerrod Sanders
# Joanne Calderwood
# Bubba Bush
# Valentina Shevchenko
# Goran Reljic
# Israel Adesanya
# Damir Ismagulov
# Jared Cannonier
# Kevin Jackson
# Brad Kohler
# Steve Nelmark
# Mauricio Rua
# Tommy Speer
# Iliarde Santos
# Norman Parke
# Max Holloway
# Anna Elmose
# Solomon Hutcherson
# Alex Andrade
# Tom Breese
# Leandro Silva
# Rafaello Oliveira
# Danny Abbadi
# Nathan Coy
# Brian Geraghty
# Sarah Frota
# Phil Baroni
# Seohee Ham
# Omari Akhmedov
# Quinn Mulhern
# Larissa Pacheco
# Collin Hart
# Luke Barnatt
# Roland Delorme
# Cristina Stanciu
# Blagoy Ivanov
# Mark Munoz
# Marcus LeVesseur
# Wes Albritton
# Mark Hall
# Steve Kennedy
# Jeremy Stephens
# Heili Alateng
# Phillip Miller
# Mike Rodriguez
# Darrell Horcher
# Suman Mokhtarian
# Dan Hooker
# Pat Audinwood
# Mike de la Torre
# Nick Serra
# Carlo Pedersoli
# Brian Camozzi
# Naoki Inoue
# James Head
# Mallory Martin
# Ivan Jorge
# Joe Charles
# Colin Robinson
# Kelly Dullanty
# Matheus Nicolau
# Jim Mullen
# John Maguire
# Don'Tale Mayes
# Jocelyn Jones-Lybarger
# Nandor Guelmino
# Ben Wall
# Ricardo Ramos
# Felipe Silva
# Sergio Moraes
# Bob Cook
# Laverne Clark
# Brian Johnston
# Roan Carneiro
# Dan Henderson
# Stephen Bass
# Mostapha Al-Turk
# Oskar Piechota
# Donald Cerrone
# Nick Sanzo
# Chris Tickle
# Germaine de Randamie
# Josh Shockley
# Stanislav Nedkov
# Tra Telligman
# Rob Whiteford
# Oleg Taktarov
# Chance Rencountre
# Nicco Montano
# Jimi Manuwa
# Adlan Amagov
# Ulysses Gomez
# Alfonso Alcarez
# Fares Ziam
# Vik Grujic
# Justin James
# Cheick Kongo
# Pearl Gonzalez
# Weili Zhang
# Jumabieke Tuerxun
# David Bielkheden
# Yorgan De Castro
# Anderson Silva
# Johnny Case
# Sam Fulton
# James Hammortree
# Ryan McGillivray
# Fabio Maldonado
# Rostem Akman
# Peter Sobotta
# Drew McFedries
# Yuki Kondo
# Frank Mir
# Lowell Anderson
# Tyson Griffin
# Viktor Pesta
# Hyun Gyu Lim
# Sammy Morgan
# Devonte Smith
# Ryan Benoit
# Jake O'Brien
# Townsend Saunders
# Roberto Traven
# Rich Attonito
# Derrick Noble
# Luiz Dutra
# Jordan Espinosa
# Tim Hague
# Steve Berger
# Mark Coleman
# Saeed Hosseini
# Konstantin Erokhin
# Hannah Cifers
# Carlos Huachin
# Luke Zachrich
# Wuliji Buren
# Emmanuel Yarborough
# Tony Ferguson
# Ramsey Nijem
# Mike Whitehead
# David Loiseau
# Daniel Roberts
# Richard Crunkilton
# Gilbert Burns
# Justin Buchholz
# Khalid Murtazaliev
# Gegard Mousasi
# Jared Hamman
# Kendall Grove
# Mike Pierce
# Jack McGlaughlin
# Paul Daley
# Rory Markham
# Enrique Marin
# Ron van Clief
# Chanmi Jeon
# Kron Gracie
# Aiemann Zahabi
# Luiz Cane
# Sirwan Kakai
# Tony Fryklund
# Alberto Crane
# Rick Davis
# Khaos Williams
# Jesus Pinedo
# Rodolfo Vieira
# Scott Adams
# Alexander Hernandez
# Fabiano Iha
# Amir Sadollah
# Lodune Sincaid
# Benson Henderson
# Alex Chambers
# Hannah Goldy
# Paul Rodriguez
# Gabriel Gonzaga
# Don Frye
# Curt Warburton
# David Teymur
# Kevin Ferguson
# Islam Makhachev
# Dave Menne
# Takenori Sato
# Gerard Gordeau
# Alexander Volkov
# Kalindra Faria
# Roger Hollett
# Justin Eilers
# Nick Hein
# Cole Miller
# Luis Pena
# Junyong Park
# Dante Rivera
# Alexandre Ferreira
# Elvis Mutapcic
# John Hathaway
# Waylon Lowe
# Thiago Silva
# Anistavio Medeiros
# Bruno Silva
# Roman Mitichyan
# Damon Jackson
# Chris Sanford
# Carls John De Tomas
# Tim Sylvia
# Koji Kitao
# Asbel Cancio
# Vinicius Queiroz
# Jordan Mein
# Markus Perez
# Tom Blackledge
# Hunter Azure
# Brandon Melendez
# Thomas Almeida
# Ernie Verdicia
# Eiji Mitsuoka
# Alex Nicholson
# Michael Bisping
# Jason MacDonald
# Ning Guangyou
# Humberto Bandenay
# Nah-Shon Burrell
# Jack May
# Renan Barao
# Hakeem Dawodu
# Jairzinho Rozenstruik
# Joachim Christensen
# Karine Gevorgyan
# Shane Nelson
# Manny Bermudez
# Dominic Waters
# Roland Payne
# Dominick Reyes
# Colton Smith
# Ian Heinisch
# Paulo Costa
# Tristan Connelly
# Mike van Arsdale
# Lina Lansberg
# Tai Bowden
# Raphael Assuncao
# Paul Georgieff
# Brendan Allen
# Luigi Vendramini
# Steve Bruno
# Shamil Abdurakhimov
# Tito Ortiz
# Iuri Alcantara
# Matthew Lopez
# Joseph Morales
# Maia Stevenson
# Lewis Gonzalez
# Richard Walsh
# Geza Kalman
# Yusuke Kasuya
# Austin Lingo
# Paulo Thiago
# Vernon Ramos
# Gerry Harris
# Josh Stansbury
# Matt Brown
# Houston Dorr
# Brian Cobb
# Yana Kunitskaya
# John Lober
# Richie Hightower
# Johnny Rhodes
# Stevie Ray
# Liu Pingyuan
# John Campetella
# Dwayne Cason
# Gil Castillo
# Magomed Mustafaev
# Thiago Alves
# Tecia Torres
# Kyle Nelson
# Lee Murray
# Fredson Paixao
# DaMarques Johnson
# Travis Browne
# Kenan Song
# Julianna Pena
# Randy Costa
# Ben Sosoli
# Nathaniel Wood
# Jon Hess
# Brian Ebersole
# Chico Camus
# Wendell Oliveira
# Marc Diakiese
# Terry Etim
# Oliver Enkamp
# Mike Nickels
# Aleksandar Rakic
# Aaron Wilkinson
# Eddie Alvarez
# Miguel Torres
# Jake Lindsey
# Maurice Smith
# Scott Smith
# Antonio McKee
# Michel Batista
# Stefan Sekulic
# Karo Parisyan
# Aaron Phillips
# Darrick Minner
# Bradley Scott
# Elias Theodorou
# Karol Rosa
# Mike Russow
# Francis Carmont
# Ryan Roberts
# Ryan MacDonald
# Mizuto Hirota
# Daniel Pineda
# Dashon Johnson
# Yaotzin Meza
# Viviane Araujo
# Jose Quinonez
# Anthony Johnson
# Ruslan Magomedov
# Neil Grove
# Sarah Kaufman
# Brian Houston
# Vince Morales
# Andrei Arlovski
# Antonio Mendes
# Rolando Delgado
# Roosevelt Roberts
# Karl Roberson
# Abdul-Kerim Edilov
# Brad Riddell
# Jeff Joslin
# Razak Al-Hassan
# Damir Hadzovic
# Gillian Robertson
# Filip Pejic
# Patrick Williams
# Ivan Salaverry
# John Gunther
# Lerone Murphy
# Ricardo Lamas
# Niklas Backstrom
# Felicia Spencer
# Roger Narvaez
# Diego Nunes
# Douglas Silva de Andrade
# Kevin Holland
# Tateki Matsuda
# Chris Weidman
# Josh Copeland
# Jesse Lennox
# Danaa Batgerel
# Roger Bowling
# Johnny Rees
# Joe Lauzon
# David Zawada
# Cameron Dollar
# Takanori Gomi
# George Roop
# Denis Kang
# Billy Miles
# Tim Kennedy
# Alexander Gustafsson
# Mike Ricci
# Su Mudaerji
# Lucie Pudilova
# Augusto Mendes
# Joanna Jedrzejczyk
# Justin Martin
# Brian Foster
# Ali Bagautinov
# Craig White
# Amanda Lemos
# He-Man Gipson
# Steven Graham
# Yosdenis Cedeno
# JC Cottrell
# Cat Zingano
# Damian Grabowski
# Michael Graves
# Scott Bessac
# Akira Corassani
# Paul Redmond
# Roy Nelson
# Dequan Townsend
# Yoshinori Horie
# Todd Butler
# Charles Rosa
# DeAnna Bennett
# Din Thomas
# Mark Eddiva
# Jodie Esquibel
# Chris Spang
# David Terrell
# Alan Belcher
# Edmen Shahbazyan
# Chris Condo
# Raphael Pessoa
# Rob Yundt
# Sijara Eubanks
# Demian Maia
# Royce Gracie
# Damian Stasiak
# Bart Palaszewski
# Cyrille Diabate
# Steve Byrnes
# Gabriel Benitez
# Mizuki Inoue
# Paul Herrera
# Reuben Duran
# Augusto Sakai
# Jens Pulver
# Michael McBride
# Katsunori Kikuno
# Falaniko Vitale
# Muslim Salikhov
# Roxanne Modafferi
# Hector Sandoval
# Marcelo Aguiar
# Renee Forte
# Frank Caracci
# Leonardo Morales
# Ron Faircloth
# Minoki Ichihara
# Jason Novelli
# Jordan Radev
# Chris Gutierrez
# Sean Brady
# Mark Robinson
# Masio Fullen
# Chris Avila
# Shinsho Anzai
# Yuri Vaulin
# Sean Woodson
# Gokhan Saki
# Valerie Letourneau
# Joey Beltran
# Patrick Smith
# Abu Azaitar
# Miles Johns
# Reese Andy
# Larry Cureton
# Ryan Couture
# Daniel Omielanczuk
# Barb Honchak
# Dan Hardy
# Andy Wang
# Veronica Macedo
# Rose Namajunas
# Jorge Masvidal
# Zak Ottow
# Dan Cramer
# Norifumi Yamamoto
# Deron Winn
# Ben Saunders
# Chael Sonnen
# Takeya Mizugaki
# Josh Clopton
# Brad Imes
# Fabricio Werdum
# Brendan O'Reilly
# David Levicki
# Jason Brilz
# Jackie Lee
# Nordine Taleb
# Neil Seery
# Eddie Mendez
# Tyson Pedro
# Icho Larenas
# David Michaud
# Cesar Arzamendia
# John Lewis
# Maximo Blanco
# Stephen Thompson
# Randa Markos
# Jason Saggo
# Alexis Dufresne
# Alberto Mina
# Anthony Perosh
# Tim Means
# James Zikic
# Hector Urbina
# Zak Cummings
# Vitor Miranda
# Chas Skelly
# Domingo Pilarte
# Luke Jumeau
# Alexis Davis
# Ryan LaFlare
# Mikey Burnett
# Dan Lauzon
# Shane Young
# Tom Lawlor
# Paige VanZant
# Brad Gumm
# Jalin Turner
# Harry Moskowitz
# Wellington Turman
# Krzysztof Jotko
# Lyman Good
# Loma Lookboonmee
# Wesley Correira
# Anthony Christodoulou
# Herbert Burns
# Jake Rosholt
# Diego Saraiva
# Ross Pearson
# Carlos Eduardo Rocha
# Daiju Takase
# Carlo Prater
# David Heath
# Izabela Badurek
# Sam Stout
# Thaddeus Luster
# Ricco Rodriguez
# Pat Healy
# Ovince Saint Preux
# Molly McCann
# Shane Primm
# Michael Johnson
# Brock Lesnar
# Daichi Abe
# Drew Dober
# Liz Carmouche
# Mike Ciesnolevicz
# Mackens Semerzier
# Thibault Gouti
# Allan Zuniga
# Hans Stringer
# Court McGee
# Luana Carolina
# Johnny Eduardo
# Elias Silverio
# Youssef Zalal
# Nate Quarry
# Antonio Carlos Junior
# Igor Pokrajac
# Floyd Sword
# Anthony Rocco Martin
# Sarah Moras
# Jay Silva
# Jack Nilson
# Jon Tuck
# Eric Wisely
# Lance Benoist
# Jamahal Hill
# Albert Morales
# Richie Vaculik
# Rory Singer
# Roberto Sanchez
# Gilbert Smith
# Jesse Ronson
# Ryo Chonan
# Rolando Dy
# Olivier Aubin-Mercier
# Chris Beal
# Dustin Pague
# Claude Patrick
# Mike King
# David Kaplan
# Cole Smith
# Shanna Young
# Mike Kyle
# Chuck O'Neil
# Chris Kelades
# Courtney Turner
# Mike Grundy
# Cody East
# Matt Veach
# Hernani Perpetuo
# Ivan Menjivar
# Rainy Martinez
# Roldan Sangcha-an
# Irene Aldana
# Brian Stann
# Zach Makovsky
# Alex Oliveira
# Tony Sims
# Issei Tamura
# Jonathan Meunier
# Nate Landwehr
# Erick Silva
# Sione Latu
# Joel Alvarez
# Per Eklund
# Cody Pfister
# Al Iaquinta
# Krzysztof Soszynski
# Michel Pereira
# Marco Ruas
# Ricky Simon
# Kevin Rosier
# Jesse Sanders
# Darrill Schoonover
# Manuel Rodriguez
# Clifford Starks
# Wilson Reis
# David Hood
# Talita Bernardo
# Mike Massenzio
# Nick Osipczak
# Rick Story
# Kristof Midoux
# Matt Sayles
# Jay Hieron
# Chris Haseman
# Jason Lambert
# Michael Trizano
# Poliana Botelho
# Rafael Feijao
# Marcin Bandel
# Jason Godsey
# Bubba McDaniel
# CB Dollaway
# Zach Light
# Cole Escovedo
# Rosi Sexton
# Corey Anderson
# Michel Quinones
# Yao Zhikui
# Brock Larson
# Bryan Caraway
# Yves Edwards
# Cortney Casey
# Andrei Semenov
# John Kolosci
# Andre Ewell
# Dennis Siver
# Daron Cruickshank
# Tom Niinimaki
# Soa Palelei
# Keiichiro Yamamiya
# Tony Gravely
# Josh Stuart
# Kyler Phillips
# Steve Lopez
# Jonathan Wiezorek
# Josh Grispi
# Julio Paulino
# Antonio Arroyo
# Matt Hughes
# Edward Faaloloto
# Travis Lutter
# James Vick
# Tom Murphy
# Pete Williams
# Kajan Johnson
# Cris Cyborg
# Holly Holm
# Marcin Prachnio
# Jacob Kilburn
# Brandon Thatch
# Ken Shamrock
# Junior Dos Santos
# Lance Gibson
# Yoshiki Takahashi
# Phillipe Nover
# Abner Lloveras
# Michinori Tanaka
# Brock Jardine
# Edson Barboza
# Punahele Soriano
# Georges St-Pierre
# Darren Uyenoyama
# Joe Duffy
# Ariane Lipski
# Uriah Hall
# Pat Barry
# Keita Nakamura
# Cory Sandhagen
# Victor Valimaki
# Matt Lucas
# Royce Alger
# Andrew Holbrook
# Dan Moret
# Marcelo Mello
# Bethe Correia
# Josh Culibao
# Logan Clark
# Tomasz Drwal
# Ericka Almeida
# Matt Schnell
# Misha Cirkunov
# Brad Morris
# Tom Watson
# Jay Cucciniello
# Kevin Randleman
# Steve Vigneault
# Dominique Steele
# Dean Lister
# Don Madge
# Tracy Cortez
# Luke Caudillo
# Shane Carwin
# Jeremy Kennedy
# Leo Kuntz
# Joseph Sandoval
# Andreas Stahl
# Antoni Hardonk
# An Ying Wang
# Mads Burnell
# Ryan Parker
# Jeff Hughes
# Jessica Andrade
# Rafael Dos Anjos
# Maycee Barber
# Terry Martin
# Ismail Naurdiev
# Marcio Cruz
# Gerald Meerschaert
# Tony DeSouza
# Maciej Jewtuszko
# Neil Wain
# Joey Gilbert
# Pedro Munhoz
# Anthony Njokuani
# Bruno Korea
# Chris Camozzi
# Kevin Souza
# George Sullivan
# Jessica-Rose Clark
# Che Mills
# Felix Lee Mitchell
# Jason DeLucia
# Santiago Ponzinibbio
# Vicente Luque
# Ode Osbourne
# Sean Gannon
# Joshua Burkman
# Ron Stallings
# Willie Gates
# Tyson Nam
# Kenny Robertson
# Alberta Cerra Leon
# Sung Bin Jo
# Nadia Kassem
# Paddy Holohan
# Steve Montgomery
# Jessin Ayari
# John Allan
# Steve Judson
# Josh Haynes
# Philip De Fries
# Jon Fitch
# Dennis Bermudez
# Claudio Silva
# Jacob Volkmann
# Nik Lentz
# JJ Aldrich
# Cody Gibson
# Ian McCall
# Jared Gordon
# Hugo Duarte
# Anton Kuivanen
# Sabina Mazo
# Jimmy Crute
# Alen Amedovski
# Felipe Arantes
# Stevie Lynch
# Joe Jordan
# Derrick Krantz
# Nick Roehrick
# Kiichi Kunimoto
# Sabah Homasi
# Ross Pointon
# Troy Mandaloniz
# Christophe Leninger
# Klidson Abreu
# Lauren Murphy
# Roman Salazar
# Marcos Mariano
# Adam Milstead
# Kyle Noke
# Ansar Chalangov
# Dmitri Stepanov
# BJ Penn
# Rogerio Nogueira
# Romie Aram
# Lucas Martins
# Mackenzie Dern
# Ricardo Romero
# Heath Herring
# Remco Pardoel
# Khalil Rountree Jr.
# Alvaro Herrera
# Da-Un Jung
# Joe Pardo
# Calvin Kattar
# Miranda Granger
# Juliana Lima
# Dmitrii Smoliakov
# Edwin DeWees
# Shane Roller
# Gleison Tibau
# Justin McCully
# Frank Camacho
# Josh Hendricks
# Henry Martinez
# Jon Madsen
# Leslie Smith
# Movsar Evloev
# Charles Byrd
# Mark Scanlon
# Lisa Ellis
# Benito Lopez
# David Roberts
# Nad Narimani
# Valmir Lazaro
# Alessio Di Chirico
# Urijah Faber
# Keigo Kunihara
# Shane Campbell
# Ciryl Gane
# Justin Frazier
# Zu Anyanwu
# Khama Worthy
# Journey Newson
# Brandon Moreno
# Joe Stevenson
# John Alessio
# Amaury Bitetti
# Gasan Umalatov
# Bernardo Magalhaes
# Jacare Souza
# Alex Caceres
# Amar Suloev
# Fabricio Camoes
# Marvin Vettori
# Paul Sass
# Zhang Lipeng
# Matt Van Buren
# Brad Katona
# Valeri Ignatov
# Shonie Carter
# Eddie Ruiz
# Luis Ramos
# Cody Donovan
# John Albert
# Eduardo Garagorri
# Brian Kelleher
# Cody McKenzie
# Sara McMann
# Sean Salmon
# Riki Fukuda
# Ulka Sasaki
# Ildemar Alcantara
# Marlon Vera
# Jinsoo Son
# Brok Weaver
# Paulo Santos
# Drakkar Klose
# Yan Cabral
# Milton Vieira
# Colin Fletcher
# Rich Clementi
# Nick Thompson
# Scott Baker
# Gray Maynard
# Adriano Martins
# Virna Jandiroba
# Bobby Nash
# Ruan Potts
# Daniel Sarafian
# Arjan Bhullar
# Brad Blackburn
# Rashid Magomedov
# Francisco Rivera
# Eddie Sanchez
# Zelim Imadaev
# Wagner Prado
# Alessio Sakara
# Travis Wiuff
# Glover Teixeira
# Alex Gorgees
# Christian Morecraft
# David Baron
# Montana De La Rosa
# Tatsuya Kawajiri
# Alejandro Perez
# Nam Phan
# Joe Slick
# Joseph Benavidez
# Amanda Nunes
# Yancy Medeiros
# Rick Glenn
# Erick Montano
# Elvis Sinosic
# Marcus Brimage
# Antonio Dos Santos
# Melton Bowen
# Jarred Brooks
# Josh Shockman
# Rob Wilkinson
# Dileno Lopes
# Dan Ige
# Raulian Paiva
# Mara Romero Borella
# Miguel Baeza
# Diego Sanchez
# Antonio Silva
# Nate Diaz
# Fabio Gurgel
# Sheila Gaff
# Joe Gigliotti
# Clay Harvison
# Juan Adams
# Joe Son
# Cory Walmsley
# Michael Patt
# Efrain Escudero
# Ben Nguyen
# Sam Hoger
# Duane Ludwig
# Neil Magny
# Gregor Gillespie
# Greg Hardy
# James Wilks
# Jamie Yager
# Kai Kara-France
# Shane del Rosario
# Juan Puig
# Murilo Bustamante
# Hayato Sakurai
# Dmitry Sosnovskiy
# John Teixeira
# Jarjis Danho
# Zarah Fairn
# James Lee
# Kennedy Nzechukwu
# Julia Avila
# Matt Serra
# Mac Danzig
# Kyle Prepolec
# Matt Andersen
# Donnie Chappell
# Nick Penner
# Justin Lawrence
# Makwan Amirkhani
# Zabit Magomedsharipov
# Jonathan Pearce
# Magomed Bibulatov
# Daniel Spohn
# Jamie Moyle
# Andre Muniz
# Ryan Hall
# Bobby Green
# Vinny Magalhaes
# John Halverson
# Teruto Ishihara
# Saparbeg Safarov
# Jimy Hettes
# George Sotiropoulos
# Bevon Lewis
# Brendan Schaub
# Tim Credeur
# Charlie Valencia
# Daniel Rodriguez
# Demetrious Johnson
# Galore Bofando
# Thiago Tavares
# Andrew Craig
# Dennis Hallman
# Danny Martinez
# Takashi Sato
# Tor Troeng
# Elizeu Zaleski dos Santos
# Taylor Lapilus
# John Cofer
# Nico Musoke
# Martin Kampmann
# Vaughan Lee
# Leonardo Mafra
# Ronda Rousey
# Dwight Grant
# Melinda Fabian
# Kelvin Gastelum
# Justin Levens
# Nicolae Negumereanu
# Anton Zafir
# Chris Cope
# David Lee
# Eddie Gordon
# Nick Pace
# Leah Letson
# Tiago Trator
# Francis Ngannou
# Jeremy Horn
# Edgar Garcia
# James Mulheron
# Fred Ettish
# Kevin Casey
# Alexandre Dantas
# Rousimar Palhares
# Jennifer Maia
# Pablo Garza
# Tyler Toner
# Joe Ellenberger
# Marc-Andre Barriault
# Shayna Baszler
# Matt Dwyer
# TJ Waldburger
# Evan Tanner
# Alberto Uda
# Jessica Aguilar
# David Mitchell
# Teemu Packalen
# Mairbek Taisumov
# James Krause
# Marcus Jones
# Callan Potter
# Alexandre Barros
# Andre Fili
# Will Campuzano
# Phil Davis
# Julian Erosa
# Bec Rawlings
# Sergey Khandozhko
# Greg Stott
# Ricardo Almeida
# Travis Fulton
# Christian Colombo
# Richardson Moreira
# Junior Hernandez
# Jason Gilliam
# Jeremy Kimball
# Leonard Garcia
# Anthony Torres
# Leigh Remedios
# Andy Anderson
# Chris Lytle
# Brodie Farber
# Pannie Kianzad
# Jared Rosholt
# John Moraga
# Justine Kish
# Darren Elkins
# Walel Watson
# Peggy Morgan
# Clint Hester
# Jake Collier
# Pawel Pawlak
# Jesse Bongfeldt
# Jerry Bohlander
# Levan Makashvili
# Seth Petruzelli
# Luke Cummo
# Rodrigo Ruas
# Sodiq Yusuff
# Lorenz Larkin
# Augusto Montano
# Rani Yahya
# Jeff Newton
# Joe Giannetti
# Guy Mezger
# Jesse Forbes
# Felipe Olivieri
# Carlos Newton
# Giga Chikadze
# Luigi Fioravanti
# Jutaro Nakao
# Robert Lucarelli
# Robert Peralta
# Luke Sanders
# Polyana Viana
# Frankie Perez
# Onassis Parungao
# Teila Tuli
# Delson Heleno
# Chase Hooper
# Scott Ferrozzo
# CJ Fernandes
# Francisco Trevino
# Jeff Hougland
# Steve Garcia
# Dave Strasser
# Julie Kedzie
# Cynthia Calvillo
# James Bochnovic
# Dong Hyun Ma
# Kyoji Horiguchi
# Matt Hamill
# Aleksei Oleinik
# Shane Burgos
# Boston Salmon
# Besam Yousef
# Charlie Brenneman
# Tim Williams
# Andy Enz
# John Dodson
# Jordan Johnson
# Grant Dawson
# Erik Koch
# Cathal Pendred
# Genki Sudo
# Jan Blachowicz
# Tae Hyun Bang
# Joao Pierini
# Cory Hendricks
# David Dvorak
# Justin Salas
# Ricky Rainey
# Kazushi Sakuraba
# Todd Brown
# Paul Taylor
# Justin Jones
# Rustam Khabilov
# Vanessa Melo
# Frankie Saenz
# Jermaine Andre
# Dong Hyun Kim
# Cyril Asker
# Kelly Faszholz
# Martin Bravo
# Leonardo Santos
# Greg Soto
# Jimmie Rivera
# Tim McKenzie
# Mark Weir
# Luan Chagas
# Macy Chiasson
# Darren Till
# Geraldo de Freitas
# Nicolas Dalby
# Kuniyoshi Hironaka
# Roman Kopylov
# Antonio Banuelos
# Josh Samman
# Mickey Gall
# Justin Gaethje
# Nolan Ticman
# Cindy Dandois
# Shannon Gugerty
# Kenichi Yamamoto
# Noad Lahat
# Sako Chivitchian
# Michihiro Omigawa
# Patrick Cote
# Justin Scoggins
# Dave Beneteau
# Mike Swick
# Yui Chul Nam
# Pascal Krauss
# Jon Manley
# Eliot Marshall
# Cale Yarbrough
# John Gunderson
# Eric Shelton
# Omar Morales
# Megan Anderson
# Alexandre Pantoja
# Laureano Staropoli
# Dustin Hazelett
# Bristol Marunde
# Darren Stewart
# Azamat Gashimov
# Wanderlei Silva
# Rodrigo Damm
# Ji Yeon Kim
# Carlos Barreto
# Darrel Gholar
# TJ Grant
# Harold Howard
# Alex Garcia
# Bryan Barberena
# Joe Proctor
# Chuck Liddell
# Piotr Hallmann
# Denis Stojnic
# Alonzo Menifield
# Rodrigo de Lima
# Ray Borg
# Joe Soto
# Andre Roberts
# Jamie Varner
# Chris Wilson
# Josh Thomson
# Art Jimmerson
# Danny Downes
# Ryan Spann
# Sean Daugherty
# SeungWoo Choi
# Kyle Bradley
# Joel Sutton
# Roger Gracie
# Orlando Wiet
# Danny Roberts
# Kevin Burns
# Jason Day
# Kurt Holobaugh
# Lucio Linhares
# Kyung Ho Kang
# Julija Stoliarenko
# Mark Kerr
# Rob Broughton
# Jessamyn Duke
# Shane Howell
# James Irvin
# Francisco Trinaldo
# Jake Matthews
# Syuri Kondo
# Wes Combs
# Jess Liaudin
# CM Punk
# Ryan Madigan
# Nate Marquardt
# Jeff Curran
# Phil Johns
# Wade Shipp
# Mats Nilsson
# Allen Crowder
# Carmelo Marrero
# Billy Quarantillo
# Kurt Pellegrino
# Gilbert Melendez
# Ricardo Abreu
# Deiveson Figueiredo
# Brandon Wolff
# Paul Kelly
# Marcin Wrzosek
# Renzo Gracie
# Ryan Jensen
# Alex Perez
# Flavio Luiz Moura
# Sean Spencer
# Yoshiyuki Yoshida
# Marcos Rogerio de Lima
# Eric Martin
# Corey Hill
# Bentley Syler
# Ramazan Emeev
# Marcelo Golm
# Elias Garcia
# Scott Junk
# Vinicius Moreira
# Ednaldo Oliveira
# Zubaira Tukhugov
# Yushin Okami
# Steve Jennum
# Jason Tan
# Jeremy Jackson
# Josh Barnett
# Mark Godbeer
# Jason Fairn
# Bill Mahood
# Joaquim Silva
# Allen Berube
# Siyar Bahadurzada
# Dongi Yang
# Bobby Southworth
# Kristian Rothaermel
# Wilson Gouveia
# Erik Perez
# Joe Solecki
# Mike Rio
# Gadzhimurad Antigulov
# Jamie Mullarkey
# Bobby Hoffman
# Yoislandy Izquierdo
# Edilberto de Oliveira
# Kazuhiro Nakamura
# Derek Downey
# Yoshihiro Akiyama
# Tatiana Suarez
# Jonathan Brookins
# Henrique da Silva
# Max Griffin
# Josh Ferguson
# Jussier Formiga
# Tonya Evinger
# Joby Sanchez
# Nick Ring
# Dokonjonosuke Mishima
# John Polakowski
# Chris Brennan
# Derek Brunson
# Belal Muhammad
# Askar Askarov
# Priscila Cachoeira
# Ivan Serati
# Brian Bowles
# Trevin Giles
# Adam Cella
# Buddy Roberts
# Akihiro Gono
# Chris Cariaso
# Jason Black
# Jason Miller
# Chris Saunders
# Jose Maria
# David Abbott
# Dan Christison
# Dave Berry
# Emily Whitmire
# Ernest Chavez
# Maryna Moroz
# Pedro Rizzo
# Khalid Taha
# Andre Winner
# Alistair Overeem
# Ian Freeman
# Ashley Yoder
# Patrick Walsh
# Yves Jabouin
# Sean O'Malley
# Mike Wessel
# Brianna Van Buren
# Matt Hobar
# Ryan Janes
# Chad Mendes
# Rex Holman
# Todd Medina
# Bea Malecki
# Tedd Williams
# Renato Moicano
# Felice Herrig
# Francimar Barroso
# John Marsh
# Andy Ogle
# Will Brooks
# Rony Jason
# Louis Gaudinot
# Ryan Thomas
# Danielle Taylor
# Tsuyoshi Kohsaka
# Brendan Loughnane
# Mike Rhodes
# Nasrat Haqparast
# Marcus Davis
# Michael Kuiper
# KJ Noons
# Mitch Gagnon
# Jack Shore
# Sam Sicilia
# Fernando Bruno
# Steven Peterson
# Rodney Wallace
# Kyle Kingsbury
# Miesha Tate
# Eric Spicely
# Ariel Beck
# Ketlen Vieira
# Geoff Neal
# Royston Wee
# Keith Jardine
# Ronald Jhun
# Raoni Barcelos
# Phil Harris
# Justin Ledet
# Matt Mitrione
# Terrion Ware
# Alex Hunter
# Tony Halme
# Chris Heatherly
# Kris McCray
# Moti Horenstein
# Jason Knight
# Kyle Stewart
# Andre Pederneiras
# Anderson Dos Santos
# Edwin Figueroa
# Ryan Jimmo
# Mike Santiago
# Mario Bautista
# Mike Easton
# Naoyuki Kotani
# Martin Svensson
# Ronny Markes
# Sean Soriano
# Ben Rothwell
# Angela Magana
# Todd Duffee
# Daniel Kelly
# Enrique Barzola
# Joao Zeferino
# Javier Vazquez
# Spike Carlyle
# Scott Morris
# Chris Fishgold
# Amanda Ribas
# Austin Arnett
# Keith Hackney
# Crafton Wallace
# Marcin Held
# Cody Stamann
# Alessandro Ricci
# Matt Grice
# Darrell Montague
# Merab Dvalishvili
# Chad Laprise
# Joey Roberts
# James Moontasri
# Danny Mitchell
# Jordan Rinaldi
# Ryan Bader
# Mike Stumpf
# Ariane Carnelossi
# CJ Keith
# Tim Gorman
# Mark Holst
# Kwan Ho Kwak
# Akbarh Arreola
# Mark Schultz
# Geane Herrera
# Alex White
# Thiago Perpetuo
# Emily Peters Kagan
# John Makdessi
# Johnny Walker
# Tiequan Zhang
# Renato Verissimo
# John Lineker
# Isaac Vallie-Flagg
# Aleksa Camur
# David Dodd
# Diego Brandao
# Khadis Ibragimov
# Mirko Cro Cop
# Yasuhiro Urushitani
# Jeremy Larsen
# Frank Hamaker
# Alex Da Silva
# Pete Spratt
# Danilo Belluardo
# Xiaonan Yan
# Chan Sung Jung
# Rodolfo Rubio
# Clay Guida
# Junior Albini
# Hector Aldana
# Kazuki Tokudome
# Jared Rollins
# Gerald Harris
# Jason Von Flue
# Benny Alloway
# Maki Pitolo
# Mickael Lebout
# Michael Chiesa
# Anthony Birchak
# Kyle Bochniak
# Tony Petarra
# Tai Tuivasa
# Dan Severn
# Stephan Bonnar
# Randy Brown
# Joe Veres
# Julian Sanchez
# Adriano Santos
# Paul Bradley
# Anthony Hamilton
# Jessica Penne
# Keith Rockel
# Mitch Clarke
# Vinc Pichel
# Christina Marks
# Marion Reneau
# Tim Lajcik
# Tim Boetsch
# Chris Wade
# Kalib Starnes
# Rafael Fiziev
# TJ Dillashaw
# Jorge Patino
# John Matua
# Brad Pickett
# Bob Gilstrap
# Tim Elliott
# Damacio Page
# Jeff Cox
# Marcin Tybura
# Papy Abedi
# Shawn Jordan
# James McSweeney
# Eryk Anders
# Kenny Florian
# Jorge Rivera
# Sean O'Connell
# Tiki Ghosn
# Aljamain Sterling
# Anthony Pettis
# Mirsad Bektic
# Rory MacDonald
# Dave Herman
# Alvin Robinson
# Salim Touahri
# Yair Rodriguez
# Nate Loughran
# Jeff Monson
# Montel Jackson
# Andre Gusmao
# Dan Stittgen
# Brandon Davis
# Manvel Gamburyan
# Devin Clark
# Tom Gallicchio
# Eddie Yagin
# Mayra Bueno Silva
# Tim Johnson
# Clay Collard
# Leonardo Augusto Leleco
# Gabe Ruediger
# Melvin Guillard
# Vladimir Matyushenko
# Ronys Torres
# Juan Espino
# Jonathan Wilson
# Keith Wisniewski
# Ion Cutelaba
# Marina Rodriguez
# Alan Patrick
# Jon Koppenhaver
# Horacio Gutierrez
# Alex Morono
# Justin Willis
# Kit Cope
# Ikuhisa Minowa
# Dalcha Lungiambula
# Eugene Jackson
# Pat Miletich
# Aaron Brink
# Hayder Hassan
# Alan Jouban
# Kevin Aguilar
# Mark Bocek
# Mike Wilkinson
# Thales Leites
# Matthew Riddle
# Damien Brown
# Michael McDonald
# Guido Cannetti
# Alexander Yakovlev
# Estevan Payan
# Dan Miller
# Junior Assuncao
# Julian Marquez
# Andre Soukhamthath
# Jose Aldo
# James Toney
# Rameau Thierry Sokoudjou
# Rashad Coulter
# Sam Alvey
# Hector Ramirez
# Steven Siler
# Alex Soto
# Jim Miller
# Josh Neer
# Jules Bruchez
# Leandro Issa
# Tyrone Roberts
# Danny Castillo
# Jose Torres
# Viscardi Andrade
# Karlos Vemola
# Cub Swanson
# TJ O'Brien
# Gilbert Aldana
# Stipe Miocic
# Gilbert Yvel
# Robert Drysdale
# Satoshi Honma
# Louis Smolka
# David Branch
# Austin Hubbard
# Frank Trigg
# Warlley Alves
# TJ Brown
# Nina Ansaroff
# Motonobu Tezuka
# Joe Vedepo
# Zane Frazier
# Nazareno Malegarie
# Francesco Maturi
# Jianping Yang
# Doug Evans
# Derrick Lewis
# Norma Dumont
# Grigorii Popov
# Vagner Rocha
# Reza Nasri
# Chris Leben
# Renato Sobral
# Aspen Ladd
# Amanda Cooper
# Anthony Smith
# Cung Le
# Viviane Pereira
# Joe Riggs
# Marcio Alexandre Junior
# Masutatsu Yano
# Maiquel Falcao
# Chris Indich
# Semmy Schilt
# Aaron Simpson
# Bojan Mihajlovic
# Mark Hughes
# Nissen Osterneck
# Petr Yan
# Guilherme Vasconcelos
# Duda Santana
# Katsuhisa Fujii
# Antonina Shevchenko
# Claudio Puelles
# Junie Browning
# Marcel Fortuna
# Bobby Moffett
# Ian Entwistle
# Kyle Watson
# Karolina Kowalkiewicz
# Diana Belbita
# Magomed Ankalaev
# Chad Reiner
# Drew Fickett
# Jake Ellenberger
# Rich Franklin
# Cody Garbrandt
# Albert Cheng
# Niko Price
# Gan McGee
# Carla Esparza
# Thiago Moises
# Daniel Cormier
# Bryce Mitchell
# Mark Madsen
# Bruno Santos
# Wallid Ismail
# Gavin Tucker
# Charles McCarthy
# Livinha Souza
# Roger Huerta
# Hector Lombard
# Will Chope
# Wagner Campos
# Joe Doerksen
# Felipe Colares
# Cezar Ferreira
# Igor Araujo
# Alex Reyes
# Rob Emerson
# Amilcar Alves
# Ebenezer Fontes Braga
# Colby Covington
# Elizabeth Phillips
# Matt Frevola
# Oli Thompson
# Wang Guan
# Josh Koscheck
# Heather Jo Clark
# Dan Evensen
# Jesse Taylor
# Jimmy Quinlan
# Jorge de Oliveira
# Pat Schilling
# Cal Worsham
# Christos Giagos
# Matt Arroyo
# Sergio Pettis
# Thiago Santos
# Anthony Macias
# Brian Ortega
# Chris Tuchscherer
# Scott Holtzman
# Mario Miranda
# Noe Hernandez
# Alex Stiebling
# Joe Moreira
# Chris Dempsey
# Jamall Emmers
# Steve Bosse
# Yoji Anjo
# Assuerio Silva
# Curtis Stout
# Mike Brown
# Hermes Franca
# Wes Sims
# Isabela de Padua
# Robert Whittaker
# Alexander Volkanovski
# Justin Tafa
# Abel Trujillo
# Bartosz Fabinski
# Alptekin Ozkilic
# Reza Madadi
# Mike Lullo
# Shamar Bailey
# Aleksei Kunchenko
# Serghei Spivac
# Alex Karalexis
# Marcos Vinicius
# Keith Berish
# Dustin Jacoby
# Jason Gonzalez
# Brian Gassaway
# Rolles Gracie
# Nick Denis
# Sanae Kikuta
# Mehdi Baghdad
# Alex Torres
# Paul Felder
# Dustin Neace
# Aisling Daly
# Patrick Cummins
# Chris de la Rocha
# Michel Prazeres
# Justin Edwards
# Homer Moore
# Jake Hecht
# Luis Henrique
# Yuki Sasaki
# Evan Dunham
# Tina Lahdemaki
# Jason High
# Chris Clements
# Donny Walker
# Allan Goes
# Jingliang Li
# Sherman Pendergarst
# Lavar Johnson
# Sultan Aliev
# Sean Alvarez
# Alexandra Albu
# John Dowdy
# Justin Wren
# Casey Kenney
# Adrian Serrano
# Thomas Gifford
# Guto Inocente
# Charlie Ward
# Joe Merritt
# Forrest Petz
# Katlyn Chookagian
# Alexa Grasso
# Tulio Palhares
# Cesar Marscucci
# Marcus Bossett
# Dhiego Lima
# Dooho Choi
# Tom Duquesnoy
# Pedro Nobre
# Lara Procopio
# Ilir Latifi
# John Phillips
# Ashkan Mokhtarian
# Ricardo Funch
# Humberto Brown
# Ray Wizard
# Thomas Ramirez
# Martin Day
# Gideon Ray
# Makhmud Muradov
# Paul Craig
# Abdul Razak Alhassan
# Arman Tsarukyan
# Tom Egan
# Mike Guymon
# Michelle Waterson
# Caol Uno
# Matt Wiman
# Stefan Struve
# Nick Agallar
# Jordan Griffin
# Kazula Vargas
# Sheldon Westcott
# Xavier Foupa-Pokam
# Claudia Gadelha
# Brett Johns
# Jenel Lausa
# Marco Beltran
# Byron Bloodworth
# Kamal Shalorus
# Hacran Dias
# Paul Creighton
# William Patolino
# Sage Northcutt
# Jared Papazian
# Polo Reyes
# Frank Lester
# Ottman Azaitar
# Ben Earwood
# Dorian Price
# Eldo Xavier Dias
# Jorge Lopez
# Rashad Evans
# Minotauro Nogueira
# Kevin Lee
# Ian Loveland
# Daniel Jolly
# Liana Jojua
# Brian Melancon
# Mark Hunt
# Te Edwards
# Hatsu Hioki
# Adam Wieczorek
# Ron Waterman
# Song Yadong
# Sai Wang
# Bharat Kandare
# Tamdan McCrory
# Tyron Woodley
# Jason Thacker
# Desmond Green
# Paul Buentello
# Angela Hill
# Hu Yaozong
# Dan Barrera
# Sergei Pavlovich
# Curtis Millender
# Christian Wellisch
# Kamaru Usman
# Charles Jourdain
# Willamy Freire
# Steve Cantwell
# Leon Edwards
# Garreth McLellan
# Jonathan Martinez
# Frankie Edgar
# Robbie Lawler
# Alan Omer
# Mike Perry
# Aaron Riley
# Rob MacDonald
# Paul Jones
# Spencer Fisher
# Dan Bobish
# Masanori Kanehara
# Anthony Lapsley
# Jonavin Webb
# Conor McGregor
# Russell Doane
# Dustin Ortiz
# Diego Ferreira
# James Te Huna
# Nick Diaz
# Mark De La Rosa
# Mike Pyle
# Jason Young
# Eric Schafer
# Tyler Diamond
# Trevor Prangley
# Keith Mielke
# Joshua Sampo
# Eugenio Tadeu
# Marcus Silveira
# Jessica Eye
# Taila Santos
# James Giboo
# Richie Smullen
# Yoel Romero
# Trevor Smith
# Lyoto Machida
# Danny Henry
# Daniel Spitz
# Jorge Santiago
# Nick Catone
# Reginaldo Vieira
# Lauren Mueller
# Hugo Viana
# Nohelin Hernandez
# Cole Williams
# Rin Nakai
# Lando Vannata
# Carlos Condit
# Brandon Vera
# Godofredo Pepey
# Curtis Blaydes
# Jason Dent
# Antonio Braga Neto
# Jonathan Goulet
# Mike Davis
# Lukasz Sajewski
# Wagner Silva
# Bobby Voelker
# Josh Emmett
# Gary Goodridge
# Daniel Teymur
# Ken Stone
# Raquel Pennington
# John Howard
# Chris Holdsworth
# Ashlee Evans-Smith
# Eddie Wineland
# Frank Shamrock
# Bojan Velickovic
# Andrew Sanchez
# Gian Villante
# Forrest Griffin
# Gunnar Nelson
# Seth Baczynski
# Danillo Villefort
# Yanan Wu
# Chad Griggs
# Alex Schoenauer
# Jake Shields
# Jim Alers
# Roger Zapata
# Dustin Kimura
# Marlon Moraes
# Simeon Thoresen
# Chris Gruetzemacher
# Antonio Carvalho
# Josh Rafferty
# Cristiano Marcello
# Albert Tumenov
# Rampage Jackson
# Johnny Bedford
# Jessica Rakoczy

# %%
personal_df = pd.DataFrame()

for item in personal_dict.values():
    personal_df = pd.concat([personal_df, item], axis = 0)

# %%
personal_df
# Out:
#      Winner           R_fighter          Fighter  KD  Sig. str. %  Td %  \
# 338     win            Ray Borg    Gabriel Silva   0         0.50  0.16
# 28      win      Kyler Phillips    Gabriel Silva   0         0.31  0.33
# 33      win       Spike Carlyle       Aalon Cruz   0         0.16  0.00
# 1469    win       Sergio Moraes       Davi Ramos   0         0.28  0.00
# 1117    win          Davi Ramos       Davi Ramos   0         0.44  0.55
# ...     ...                 ...              ...  ..          ...   ...
# 2901     nc          Rani Yahya   Johnny Bedford   0         0.66  0.00
# 2775    win         Cody Gibson   Johnny Bedford   0         0.63  0.00
# 2665    win          Rani Yahya   Johnny Bedford   0         0.45  0.00
# 3045    win       Julianna Pena  Jessica Rakoczy   0         0.80  0.00
# 2371    win  Valerie Letourneau  Jessica Rakoczy   0         0.42  0.20
#
#       Sub. att  Pass  Rev.  Sig. str. Hits  ...  cum_Body Hits  \
# 338          0     1     1               8  ...            0.0
# 28           1     0     0              31  ...            0.0
# 33           0     0     0               2  ...            0.0
# 1469         0     0     0              35  ...            7.0
# 1117         1     5     0              55  ...            7.0
# ...        ...   ...   ...             ...  ...            ...
# 2901         0     0     0               4  ...           49.0
# 2775         0     0     0               7  ...           49.0
# 2665         0     3     0               9  ...           51.0
# 3045         0     0     0               4  ...            2.0
# 2371         1     2     1              46  ...            2.0
#
#       cum_Body Attempts  cum_Leg Hits  cum_Leg Attempts  cum_Distance Hits  \
# 338                 1.0           1.0               1.0                6.0
# 28                  1.0           1.0               1.0                6.0
# 33                  4.0           0.0               4.0                2.0
# 1469               17.0           7.0               8.0               35.0
# 1117               17.0           7.0               8.0               35.0
# ...                 ...           ...               ...                ...
# 2901               61.0          10.0              12.0               71.0
# 2775               61.0          10.0              12.0               73.0
# 2665               63.0          10.0              12.0               76.0
# 3045                3.0           0.0               0.0                2.0
# 2371                3.0           0.0               0.0                2.0
#
#       cum_Distance Attempts  cum_Clinch Hits  cum_Clinch Attempts  \
# 338                    12.0              2.0                  4.0
# 28                     12.0              2.0                  4.0
# 33                     12.0              0.0                  0.0
# 1469                  122.0              0.0                  0.0
# 1117                  122.0              0.0                  0.0
# ...                     ...              ...                  ...
# 2901                  196.0             27.0                 33.0
# 2775                  200.0             27.0                 33.0
# 2665                  204.0             31.0                 40.0
# 3045                    2.0              2.0                  3.0
# 2371                    2.0              2.0                  3.0
#
#       cum_Ground Hits  cum_Ground Attempts
# 338               0.0                  0.0
# 28                0.0                  0.0
# 33                0.0                  0.0
# 1469              0.0                  0.0
# 1117              0.0                  0.0
# ...               ...                  ...
# 2901             68.0                102.0
# 2775             70.0                104.0
# 2665             70.0                104.0
# 3045              0.0                  0.0
# 2371              0.0                  0.0
#
# [11086 rows x 62 columns]

# %% [markdown]
# # Finalize:

# %%
final_df = personal_df
final_df.head(5)
# Out:
#      Winner       R_fighter        Fighter  KD  Sig. str. %  Td %  Sub. att  \
# 338     win        Ray Borg  Gabriel Silva   0         0.50  0.16         0
# 28      win  Kyler Phillips  Gabriel Silva   0         0.31  0.33         1
# 33      win   Spike Carlyle     Aalon Cruz   0         0.16  0.00         0
# 1469    win   Sergio Moraes     Davi Ramos   0         0.28  0.00         0
# 1117    win      Davi Ramos     Davi Ramos   0         0.44  0.55         1
#
#       Pass  Rev.  Sig. str. Hits  ...  cum_Body Hits  cum_Body Attempts  \
# 338      1     1               8  ...            0.0                1.0
# 28       0     0              31  ...            0.0                1.0
# 33       0     0               2  ...            0.0                4.0
# 1469     0     0              35  ...            7.0               17.0
# 1117     5     0              55  ...            7.0               17.0
#
#       cum_Leg Hits  cum_Leg Attempts  cum_Distance Hits  \
# 338            1.0               1.0                6.0
# 28             1.0               1.0                6.0
# 33             0.0               4.0                2.0
# 1469           7.0               8.0               35.0
# 1117           7.0               8.0               35.0
#
#       cum_Distance Attempts  cum_Clinch Hits  cum_Clinch Attempts  \
# 338                    12.0              2.0                  4.0
# 28                     12.0              2.0                  4.0
# 33                     12.0              0.0                  0.0
# 1469                  122.0              0.0                  0.0
# 1117                  122.0              0.0                  0.0
#
#       cum_Ground Hits  cum_Ground Attempts
# 338               0.0                  0.0
# 28                0.0                  0.0
# 33                0.0                  0.0
# 1469              0.0                  0.0
# 1117              0.0                  0.0
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Calculate Efficiency:

# %%
cumulative_columns = ['cum_KD', 'cum_Sub. att', 'cum_Pass', 'cum_Rev.',
       'cum_Sig. str. Hits', 'cum_Sig. str. Attempts', 'cum_Total str. Hits',
       'cum_Total str. Attempts', 'cum_Td Hits', 'cum_Td Attempts',
       'cum_Head Hits', 'cum_Head Attempts', 'cum_Body Hits',
       'cum_Body Attempts', 'cum_Leg Hits', 'cum_Leg Attempts',
       'cum_Distance Hits', 'cum_Distance Attempts', 'cum_Clinch Hits',
       'cum_Clinch Attempts', 'cum_Ground Hits', 'cum_Ground Attempts']

# %%
#Use cumulative statistics / 10 minutes of match time (10 min. is global match time average across all fighters)
for item in cumulative_columns:
    a = round(final_df[item] / final_df['cum_match_time'] * 10,2)
    personal_df['avg_{}'.format(item)] = a

# %%
final_df.columns
# Out:
# Index(['Winner', 'R_fighter', 'Fighter', 'KD', 'Sig. str. %', 'Td %',
#        'Sub. att', 'Pass', 'Rev.', 'Sig. str. Hits', 'Sig. str. Attempts',
#        'Total str. Hits', 'Total str. Attempts', 'Td Hits', 'Td Attempts',
#        'Head Hits', 'Head Attempts', 'Body Hits', 'Body Attempts', 'Leg Hits',
#        'Leg Attempts', 'Distance Hits', 'Distance Attempts', 'Clinch Hits',
#        'Clinch Attempts', 'Ground Hits', 'Ground Attempts', 'DOB', 'Height',
#        'Reach', 'Stance', 'Weight', 'date', 'match_time', 'age', 'loss', 'win',
#        'draws', 'streak', 'cum_match_time', 'cum_KD', 'cum_Sub. att',
#        'cum_Pass', 'cum_Rev.', 'cum_Sig. str. Hits', 'cum_Sig. str. Attempts',
#        'cum_Total str. Hits', 'cum_Total str. Attempts', 'cum_Td Hits',
#        'cum_Td Attempts', 'cum_Head Hits', 'cum_Head Attempts',
#        'cum_Body Hits', 'cum_Body Attempts', 'cum_Leg Hits',
#        'cum_Leg Attempts', 'cum_Distance Hits', 'cum_Distance Attempts',
#        'cum_Clinch Hits', 'cum_Clinch Attempts', 'cum_Ground Hits',
#        'cum_Ground Attempts', 'avg_cum_KD', 'avg_cum_Sub. att', 'avg_cum_Pass',
#        'avg_cum_Rev.', 'avg_cum_Sig. str. Hits', 'avg_cum_Sig. str. Attempts',
#        'avg_cum_Total str. Hits', 'avg_cum_Total str. Attempts',
#        'avg_cum_Td Hits', 'avg_cum_Td Attempts', 'avg_cum_Head Hits',
#        'avg_cum_Head Attempts', 'avg_cum_Body Hits', 'avg_cum_Body Attempts',
#        'avg_cum_Leg Hits', 'avg_cum_Leg Attempts', 'avg_cum_Distance Hits',
#        'avg_cum_Distance Attempts', 'avg_cum_Clinch Hits',
#        'avg_cum_Clinch Attempts', 'avg_cum_Ground Hits',
#        'avg_cum_Ground Attempts'],
#       dtype='object')

# %%
drop_columns = ['KD', 'Sig. str. %', 'Td %',
       'Sub. att', 'Pass', 'Rev.', 'Sig. str. Hits', 'Sig. str. Attempts',
       'Total str. Hits', 'Total str. Attempts', 'Td Hits', 'Td Attempts',
       'Head Hits', 'Head Attempts', 'Body Hits', 'Body Attempts', 'Leg Hits',
       'Leg Attempts', 'Distance Hits', 'Distance Attempts', 'Clinch Hits',
       'Clinch Attempts', 'Ground Hits', 'Ground Attempts']

# %%
final_df.drop(drop_columns, axis = 1, inplace = True)

# %%
final_df.columns
# Out:
# Index(['Winner', 'R_fighter', 'Fighter', 'DOB', 'Height', 'Reach', 'Stance',
#        'Weight', 'date', 'match_time', 'age', 'loss', 'win', 'draws', 'streak',
#        'cum_match_time', 'cum_KD', 'cum_Sub. att', 'cum_Pass', 'cum_Rev.',
#        'cum_Sig. str. Hits', 'cum_Sig. str. Attempts', 'cum_Total str. Hits',
#        'cum_Total str. Attempts', 'cum_Td Hits', 'cum_Td Attempts',
#        'cum_Head Hits', 'cum_Head Attempts', 'cum_Body Hits',
#        'cum_Body Attempts', 'cum_Leg Hits', 'cum_Leg Attempts',
#        'cum_Distance Hits', 'cum_Distance Attempts', 'cum_Clinch Hits',
#        'cum_Clinch Attempts', 'cum_Ground Hits', 'cum_Ground Attempts',
#        'avg_cum_KD', 'avg_cum_Sub. att', 'avg_cum_Pass', 'avg_cum_Rev.',
#        'avg_cum_Sig. str. Hits', 'avg_cum_Sig. str. Attempts',
#        'avg_cum_Total str. Hits', 'avg_cum_Total str. Attempts',
#        'avg_cum_Td Hits', 'avg_cum_Td Attempts', 'avg_cum_Head Hits',
#        'avg_cum_Head Attempts', 'avg_cum_Body Hits', 'avg_cum_Body Attempts',
#        'avg_cum_Leg Hits', 'avg_cum_Leg Attempts', 'avg_cum_Distance Hits',
#        'avg_cum_Distance Attempts', 'avg_cum_Clinch Hits',
#        'avg_cum_Clinch Attempts', 'avg_cum_Ground Hits',
#        'avg_cum_Ground Attempts'],
#       dtype='object')

# %% [markdown]
# # Calculate fighter efficiency:

# %%
sig_str = final_df['cum_Sig. str. Hits'] / final_df['cum_Sig. str. Attempts']
hits = final_df['cum_Total str. Hits'] / final_df['cum_Total str. Attempts']
tds = final_df['cum_Td Hits'] / final_df['cum_Td Attempts']
head = final_df['cum_Head Hits'] / final_df['cum_Head Attempts']
leg = final_df['cum_Leg Hits'] / final_df['cum_Leg Attempts']
body = final_df['cum_Body Hits'] / final_df['cum_Body Attempts']
distance = final_df['cum_Distance Hits'] / final_df['cum_Distance Attempts']
clinch = final_df['cum_Clinch Hits'] / final_df['cum_Clinch Attempts']
ground = final_df['cum_Ground Hits'] / final_df['cum_Ground Attempts']

efficiency_stats = [sig_str, hits, tds, head, leg, body, distance, clinch, ground]
efficiency_columns = ['eff_sig_str', 'eff_hits', 'eff_tds', 'eff_head', 'eff_leg', 'eff_body', 
                      'eff_distance', 'eff_clinch', 'eff_ground']

for item in efficiency_stats:
    item.fillna(0, inplace = True)

# %%
for name, item in zip(efficiency_columns, efficiency_stats):
    final_df[name] = item
    final_df[name] = final_df[name].apply(lambda x: round(x, 2))

# %%
final_df.columns
# Out:
# Index(['Winner', 'R_fighter', 'Fighter', 'DOB', 'Height', 'Reach', 'Stance',
#        'Weight', 'date', 'match_time', 'age', 'loss', 'win', 'draws', 'streak',
#        'cum_match_time', 'cum_KD', 'cum_Sub. att', 'cum_Pass', 'cum_Rev.',
#        'cum_Sig. str. Hits', 'cum_Sig. str. Attempts', 'cum_Total str. Hits',
#        'cum_Total str. Attempts', 'cum_Td Hits', 'cum_Td Attempts',
#        'cum_Head Hits', 'cum_Head Attempts', 'cum_Body Hits',
#        'cum_Body Attempts', 'cum_Leg Hits', 'cum_Leg Attempts',
#        'cum_Distance Hits', 'cum_Distance Attempts', 'cum_Clinch Hits',
#        'cum_Clinch Attempts', 'cum_Ground Hits', 'cum_Ground Attempts',
#        'avg_cum_KD', 'avg_cum_Sub. att', 'avg_cum_Pass', 'avg_cum_Rev.',
#        'avg_cum_Sig. str. Hits', 'avg_cum_Sig. str. Attempts',
#        'avg_cum_Total str. Hits', 'avg_cum_Total str. Attempts',
#        'avg_cum_Td Hits', 'avg_cum_Td Attempts', 'avg_cum_Head Hits',
#        'avg_cum_Head Attempts', 'avg_cum_Body Hits', 'avg_cum_Body Attempts',
#        'avg_cum_Leg Hits', 'avg_cum_Leg Attempts', 'avg_cum_Distance Hits',
#        'avg_cum_Distance Attempts', 'avg_cum_Clinch Hits',
#        'avg_cum_Clinch Attempts', 'avg_cum_Ground Hits',
#        'avg_cum_Ground Attempts', 'eff_sig_str', 'eff_hits', 'eff_tds',
#        'eff_head', 'eff_leg', 'eff_body', 'eff_distance', 'eff_clinch',
#        'eff_ground'],
#       dtype='object')

# %%
drop_columns = ['cum_KD', 'cum_Sub. att', 'cum_Pass', 'cum_Rev.',
       'cum_Sig. str. Hits', 'cum_Sig. str. Attempts', 'cum_Total str. Hits',
       'cum_Total str. Attempts', 'cum_Td Hits', 'cum_Td Attempts',
       'cum_Head Hits', 'cum_Head Attempts', 'cum_Body Hits',
       'cum_Body Attempts', 'cum_Leg Hits', 'cum_Leg Attempts',
       'cum_Distance Hits', 'cum_Distance Attempts', 'cum_Clinch Hits',
       'cum_Clinch Attempts', 'cum_Ground Hits', 'cum_Ground Attempts']

# %%
final_df.drop(drop_columns, axis = 1, inplace = True)

# %%
final_df.columns
# Out:
# Index(['Winner', 'R_fighter', 'Fighter', 'DOB', 'Height', 'Reach', 'Stance',
#        'Weight', 'date', 'match_time', 'age', 'loss', 'win', 'draws', 'streak',
#        'cum_match_time', 'avg_cum_KD', 'avg_cum_Sub. att', 'avg_cum_Pass',
#        'avg_cum_Rev.', 'avg_cum_Sig. str. Hits', 'avg_cum_Sig. str. Attempts',
#        'avg_cum_Total str. Hits', 'avg_cum_Total str. Attempts',
#        'avg_cum_Td Hits', 'avg_cum_Td Attempts', 'avg_cum_Head Hits',
#        'avg_cum_Head Attempts', 'avg_cum_Body Hits', 'avg_cum_Body Attempts',
#        'avg_cum_Leg Hits', 'avg_cum_Leg Attempts', 'avg_cum_Distance Hits',
#        'avg_cum_Distance Attempts', 'avg_cum_Clinch Hits',
#        'avg_cum_Clinch Attempts', 'avg_cum_Ground Hits',
#        'avg_cum_Ground Attempts', 'eff_sig_str', 'eff_hits', 'eff_tds',
#        'eff_head', 'eff_leg', 'eff_body', 'eff_distance', 'eff_clinch',
#        'eff_ground'],
#       dtype='object')

# %% [markdown]
# Now that we have every fighter's calculated personal_df, we need to recombine them by match:

# %% [markdown]
# ### Extract Transformed data to load to MariaDB:

# %%
latest_match_db = pd.DataFrame()

for name in fighters.Name:
    print(name)
    temp = final_df[final_df['Fighter'] == name]
    try:
        latest = temp.iloc[-1, :]
        latest_match_db = latest_match_db.append(latest)
    except:
        pass
# Out:
# Gabriel Silva
# Aalon Cruz
# Davi Ramos
# Sean McCorkle
# Glaico Franca
# Dylan Andrews
# Luke Rockhold
# John Salter
# Joe Brammer
# Gina Mazany
# Rachael Ostovich
# Chase Sherman
# Benji Radach
# Caros Fodor
# Koji Oishi
# Josh Bryant
# Henry Briones
# Jason Reinhardt
# Darko Stosic
# Sean Sherk
# Abubakar Nurmagomedov
# Dustin Poirier
# Rudyard Moncayo
# Kevin Jordan
# Artem Lobov
# Trent Jenkins
# Kerry Schall
# Khabib Nurmagomedov
# Pete Sell
# Bas Rutten
# John Cholish
# Walt Harris
# Nate Schroeder
# Arnold Allen
# Jack Marshman
# Marcus Aurelio
# Matt Horwich
# Oluwale Bamgbose
# Nate Mohr
# Tanner Boser
# Jorge Gurgel
# Gerald Strebendt
# Chase Gormley
# Rob Font
# Houston Alexander
# Rob Kimmons
# Costas Philippou
# Henry Cejudo
# Jon Olav Einemo
# Marvin Eastman
# Dale Hartt
# Chris Price
# Kailin Curran
# Andrea Lee
# Mike Jackson
# Cain Carrizosa
# Devin Powell
# Scott Askham
# Maurice Greene
# Branden Lee Hinkle
# Ed Herman
# Charles Oliveira
# Milana Dudieva
# Tarec Saffiedine
# Joey Gomez
# Paul Varelans
# Rogerio Bontorin
# Jon Jones
# Volkan Oezdemir
# Tommy Hayden
# Dave Galera
# Rafael Carino
# Kimo Leopoldo
# Beneil Dariush
# Myles Jury
# Anthony Hernandez
# Johny Hendricks
# David Velasquez
# Diego Rivas
# Jack Hermansson
# Adam Yandiev
# Mark Hominick
# Randy Couture
# Ben Askren
# Steve Steinbeiss
# Scott Jorgensen
# Matt Bessette
# Fabiano Scherner
# Tom DeBlass
# Caio Magalhaes
# Jimmy Wallhead
# Brad Tavares
# Marcelo Guimaraes
# Fredy Serrano
# Enson Inoue
# Jon Delos Reyes
# Rocky Lee
# Sean Pierson
# Sheymon Moraes
# Michal Oleksiejczuk
# Sean Strickland
# Shamil Gamzatov
# Dieusel Berto
# Rafael Natal
# Matt Lindland
# Magnus Cedenblad
# Chris Liguori
# Sam Adkins
# Scott Fiedler
# Vitor Belfort
# Joao Roque
# Yuri Villefort
# Said Nurmagomedov
# Cain Velasquez
# Emil Meek
# Joey Gambino
# Shunichi Shimizu
# Igor Zinoviev
# Nikita Krylov
# Dominick Cruz
# Davey Grant
# Aaron Rosa
# Samy Schiavo
# Mario Neto
# Shana Dobson
# Vernon White
# Julio Arce
# Garett Whiteley
# Jerrod Sanders
# Joanne Calderwood
# Bubba Bush
# Valentina Shevchenko
# Goran Reljic
# Israel Adesanya
# Damir Ismagulov
# Jared Cannonier
# Kevin Jackson
# Brad Kohler
# Steve Nelmark
# Mauricio Rua
# Tommy Speer
# Iliarde Santos
# Norman Parke
# Max Holloway
# Anna Elmose
# Solomon Hutcherson
# Alex Andrade
# Tom Breese
# Leandro Silva
# Rafaello Oliveira
# Danny Abbadi
# Nathan Coy
# Brian Geraghty
# Sarah Frota
# Phil Baroni
# Seohee Ham
# Omari Akhmedov
# Quinn Mulhern
# Larissa Pacheco
# Collin Hart
# Luke Barnatt
# Roland Delorme
# Cristina Stanciu
# Blagoy Ivanov
# Mark Munoz
# Marcus LeVesseur
# Wes Albritton
# Mark Hall
# Steve Kennedy
# Jeremy Stephens
# Heili Alateng
# Phillip Miller
# Mike Rodriguez
# Darrell Horcher
# Suman Mokhtarian
# Dan Hooker
# Pat Audinwood
# Mike de la Torre
# Nick Serra
# Carlo Pedersoli
# Brian Camozzi
# Naoki Inoue
# James Head
# Mallory Martin
# Ivan Jorge
# Joe Charles
# Colin Robinson
# Kelly Dullanty
# Matheus Nicolau
# Jim Mullen
# John Maguire
# Don'Tale Mayes
# Jocelyn Jones-Lybarger
# Nandor Guelmino
# Ben Wall
# Ricardo Ramos
# Felipe Silva
# Sergio Moraes
# Bob Cook
# Laverne Clark
# Brian Johnston
# Roan Carneiro
# Dan Henderson
# Stephen Bass
# Mostapha Al-Turk
# Oskar Piechota
# Donald Cerrone
# Nick Sanzo
# Chris Tickle
# Germaine de Randamie
# Josh Shockley
# Stanislav Nedkov
# Tra Telligman
# Rob Whiteford
# Oleg Taktarov
# Chance Rencountre
# Nicco Montano
# Jimi Manuwa
# Adlan Amagov
# Ulysses Gomez
# Alfonso Alcarez
# Fares Ziam
# Vik Grujic
# Justin James
# Cheick Kongo
# Pearl Gonzalez
# Weili Zhang
# Jumabieke Tuerxun
# David Bielkheden
# Yorgan De Castro
# Anderson Silva
# Johnny Case
# Sam Fulton
# James Hammortree
# Ryan McGillivray
# Fabio Maldonado
# Rostem Akman
# Peter Sobotta
# Drew McFedries
# Yuki Kondo
# Frank Mir
# Lowell Anderson
# Tyson Griffin
# Viktor Pesta
# Hyun Gyu Lim
# Sammy Morgan
# Devonte Smith
# Ryan Benoit
# Jake O'Brien
# Townsend Saunders
# Roberto Traven
# Rich Attonito
# Derrick Noble
# Luiz Dutra
# Jordan Espinosa
# Tim Hague
# Steve Berger
# Mark Coleman
# Saeed Hosseini
# Konstantin Erokhin
# Hannah Cifers
# Carlos Huachin
# Luke Zachrich
# Wuliji Buren
# Emmanuel Yarborough
# Tony Ferguson
# Ramsey Nijem
# Mike Whitehead
# David Loiseau
# Daniel Roberts
# Richard Crunkilton
# Gilbert Burns
# Justin Buchholz
# Khalid Murtazaliev
# Gegard Mousasi
# Jared Hamman
# Kendall Grove
# Mike Pierce
# Jack McGlaughlin
# Paul Daley
# Rory Markham
# Enrique Marin
# Ron van Clief
# Chanmi Jeon
# Kron Gracie
# Aiemann Zahabi
# Luiz Cane
# Sirwan Kakai
# Tony Fryklund
# Alberto Crane
# Rick Davis
# Khaos Williams
# Jesus Pinedo
# Rodolfo Vieira
# Scott Adams
# Alexander Hernandez
# Fabiano Iha
# Amir Sadollah
# Lodune Sincaid
# Benson Henderson
# Alex Chambers
# Hannah Goldy
# Paul Rodriguez
# Gabriel Gonzaga
# Don Frye
# Curt Warburton
# David Teymur
# Kevin Ferguson
# Islam Makhachev
# Dave Menne
# Takenori Sato
# Gerard Gordeau
# Alexander Volkov
# Kalindra Faria
# Roger Hollett
# Justin Eilers
# Nick Hein
# Cole Miller
# Luis Pena
# Junyong Park
# Dante Rivera
# Alexandre Ferreira
# Elvis Mutapcic
# John Hathaway
# Waylon Lowe
# Thiago Silva
# Anistavio Medeiros
# Bruno Silva
# Roman Mitichyan
# Damon Jackson
# Chris Sanford
# Carls John De Tomas
# Tim Sylvia
# Koji Kitao
# Asbel Cancio
# Vinicius Queiroz
# Jordan Mein
# Markus Perez
# Tom Blackledge
# Hunter Azure
# Brandon Melendez
# Thomas Almeida
# Ernie Verdicia
# Eiji Mitsuoka
# Alex Nicholson
# Michael Bisping
# Jason MacDonald
# Ning Guangyou
# Humberto Bandenay
# Nah-Shon Burrell
# Jack May
# Renan Barao
# Hakeem Dawodu
# Jairzinho Rozenstruik
# Joachim Christensen
# Karine Gevorgyan
# Shane Nelson
# Manny Bermudez
# Dominic Waters
# Roland Payne
# Dominick Reyes
# Colton Smith
# Ian Heinisch
# Paulo Costa
# Tristan Connelly
# Mike van Arsdale
# Lina Lansberg
# Tai Bowden
# Raphael Assuncao
# Paul Georgieff
# Brendan Allen
# Luigi Vendramini
# Steve Bruno
# Shamil Abdurakhimov
# Tito Ortiz
# Iuri Alcantara
# Matthew Lopez
# Joseph Morales
# Maia Stevenson
# Lewis Gonzalez
# Richard Walsh
# Geza Kalman
# Yusuke Kasuya
# Austin Lingo
# Paulo Thiago
# Vernon Ramos
# Gerry Harris
# Josh Stansbury
# Matt Brown
# Houston Dorr
# Brian Cobb
# Yana Kunitskaya
# John Lober
# Richie Hightower
# Johnny Rhodes
# Stevie Ray
# Liu Pingyuan
# John Campetella
# Dwayne Cason
# Gil Castillo
# Magomed Mustafaev
# Thiago Alves
# Tecia Torres
# Kyle Nelson
# Lee Murray
# Fredson Paixao
# DaMarques Johnson
# Travis Browne
# Kenan Song
# Julianna Pena
# Randy Costa
# Ben Sosoli
# Nathaniel Wood
# Jon Hess
# Brian Ebersole
# Chico Camus
# Wendell Oliveira
# Marc Diakiese
# Terry Etim
# Oliver Enkamp
# Mike Nickels
# Aleksandar Rakic
# Aaron Wilkinson
# Eddie Alvarez
# Miguel Torres
# Jake Lindsey
# Maurice Smith
# Scott Smith
# Antonio McKee
# Michel Batista
# Stefan Sekulic
# Karo Parisyan
# Aaron Phillips
# Darrick Minner
# Bradley Scott
# Elias Theodorou
# Karol Rosa
# Mike Russow
# Francis Carmont
# Ryan Roberts
# Ryan MacDonald
# Mizuto Hirota
# Daniel Pineda
# Dashon Johnson
# Yaotzin Meza
# Viviane Araujo
# Jose Quinonez
# Anthony Johnson
# Ruslan Magomedov
# Neil Grove
# Sarah Kaufman
# Brian Houston
# Vince Morales
# Andrei Arlovski
# Antonio Mendes
# Rolando Delgado
# Roosevelt Roberts
# Karl Roberson
# Abdul-Kerim Edilov
# Brad Riddell
# Jeff Joslin
# Razak Al-Hassan
# Damir Hadzovic
# Gillian Robertson
# Filip Pejic
# Patrick Williams
# Ivan Salaverry
# John Gunther
# Lerone Murphy
# Ricardo Lamas
# Niklas Backstrom
# Felicia Spencer
# Roger Narvaez
# Diego Nunes
# Douglas Silva de Andrade
# Kevin Holland
# Tateki Matsuda
# Chris Weidman
# Josh Copeland
# Jesse Lennox
# Danaa Batgerel
# Roger Bowling
# Johnny Rees
# Joe Lauzon
# David Zawada
# Cameron Dollar
# Takanori Gomi
# George Roop
# Denis Kang
# Billy Miles
# Tim Kennedy
# Alexander Gustafsson
# Mike Ricci
# Su Mudaerji
# Lucie Pudilova
# Augusto Mendes
# Joanna Jedrzejczyk
# Justin Martin
# Brian Foster
# Ali Bagautinov
# Craig White
# Amanda Lemos
# He-Man Gipson
# Steven Graham
# Yosdenis Cedeno
# JC Cottrell
# Cat Zingano
# Damian Grabowski
# Michael Graves
# Scott Bessac
# Akira Corassani
# Paul Redmond
# Roy Nelson
# Dequan Townsend
# Yoshinori Horie
# Todd Butler
# Charles Rosa
# DeAnna Bennett
# Din Thomas
# Mark Eddiva
# Jodie Esquibel
# Chris Spang
# David Terrell
# Alan Belcher
# Edmen Shahbazyan
# Chris Condo
# Raphael Pessoa
# Rob Yundt
# Sijara Eubanks
# Demian Maia
# Royce Gracie
# Damian Stasiak
# Bart Palaszewski
# Cyrille Diabate
# Steve Byrnes
# Gabriel Benitez
# Mizuki Inoue
# Paul Herrera
# Reuben Duran
# Augusto Sakai
# Jens Pulver
# Michael McBride
# Katsunori Kikuno
# Falaniko Vitale
# Muslim Salikhov
# Roxanne Modafferi
# Hector Sandoval
# Marcelo Aguiar
# Renee Forte
# Frank Caracci
# Leonardo Morales
# Ron Faircloth
# Minoki Ichihara
# Jason Novelli
# Jordan Radev
# Chris Gutierrez
# Sean Brady
# Mark Robinson
# Masio Fullen
# Chris Avila
# Shinsho Anzai
# Yuri Vaulin
# Sean Woodson
# Gokhan Saki
# Valerie Letourneau
# Joey Beltran
# Patrick Smith
# Abu Azaitar
# Miles Johns
# Reese Andy
# Larry Cureton
# Ryan Couture
# Daniel Omielanczuk
# Barb Honchak
# Dan Hardy
# Andy Wang
# Veronica Macedo
# Rose Namajunas
# Jorge Masvidal
# Zak Ottow
# Dan Cramer
# Norifumi Yamamoto
# Deron Winn
# Ben Saunders
# Chael Sonnen
# Takeya Mizugaki
# Josh Clopton
# Brad Imes
# Fabricio Werdum
# Brendan O'Reilly
# David Levicki
# Jason Brilz
# Jackie Lee
# Nordine Taleb
# Neil Seery
# Eddie Mendez
# Tyson Pedro
# Icho Larenas
# David Michaud
# Cesar Arzamendia
# John Lewis
# Maximo Blanco
# Stephen Thompson
# Randa Markos
# Jason Saggo
# Alexis Dufresne
# Alberto Mina
# Anthony Perosh
# Tim Means
# James Zikic
# Hector Urbina
# Zak Cummings
# Vitor Miranda
# Chas Skelly
# Domingo Pilarte
# Luke Jumeau
# Alexis Davis
# Ryan LaFlare
# Mikey Burnett
# Dan Lauzon
# Shane Young
# Tom Lawlor
# Paige VanZant
# Brad Gumm
# Jalin Turner
# Harry Moskowitz
# Wellington Turman
# Krzysztof Jotko
# Lyman Good
# Loma Lookboonmee
# Wesley Correira
# Anthony Christodoulou
# Herbert Burns
# Jake Rosholt
# Diego Saraiva
# Ross Pearson
# Carlos Eduardo Rocha
# Daiju Takase
# Carlo Prater
# David Heath
# Izabela Badurek
# Sam Stout
# Thaddeus Luster
# Ricco Rodriguez
# Pat Healy
# Ovince Saint Preux
# Molly McCann
# Shane Primm
# Michael Johnson
# Brock Lesnar
# Daichi Abe
# Drew Dober
# Liz Carmouche
# Mike Ciesnolevicz
# Mackens Semerzier
# Thibault Gouti
# Allan Zuniga
# Hans Stringer
# Court McGee
# Luana Carolina
# Johnny Eduardo
# Elias Silverio
# Youssef Zalal
# Nate Quarry
# Antonio Carlos Junior
# Igor Pokrajac
# Floyd Sword
# Anthony Rocco Martin
# Sarah Moras
# Jay Silva
# Jack Nilson
# Jon Tuck
# Eric Wisely
# Lance Benoist
# Jamahal Hill
# Albert Morales
# Richie Vaculik
# Rory Singer
# Roberto Sanchez
# Gilbert Smith
# Jesse Ronson
# Ryo Chonan
# Rolando Dy
# Olivier Aubin-Mercier
# Chris Beal
# Dustin Pague
# Claude Patrick
# Mike King
# David Kaplan
# Cole Smith
# Shanna Young
# Mike Kyle
# Chuck O'Neil
# Chris Kelades
# Courtney Turner
# Mike Grundy
# Cody East
# Matt Veach
# Hernani Perpetuo
# Ivan Menjivar
# Rainy Martinez
# Roldan Sangcha-an
# Irene Aldana
# Brian Stann
# Zach Makovsky
# Alex Oliveira
# Tony Sims
# Issei Tamura
# Jonathan Meunier
# Nate Landwehr
# Erick Silva
# Sione Latu
# Joel Alvarez
# Per Eklund
# Cody Pfister
# Al Iaquinta
# Krzysztof Soszynski
# Michel Pereira
# Marco Ruas
# Ricky Simon
# Kevin Rosier
# Jesse Sanders
# Darrill Schoonover
# Manuel Rodriguez
# Clifford Starks
# Wilson Reis
# David Hood
# Talita Bernardo
# Mike Massenzio
# Nick Osipczak
# Rick Story
# Kristof Midoux
# Matt Sayles
# Jay Hieron
# Chris Haseman
# Jason Lambert
# Michael Trizano
# Poliana Botelho
# Rafael Feijao
# Marcin Bandel
# Jason Godsey
# Bubba McDaniel
# CB Dollaway
# Zach Light
# Cole Escovedo
# Rosi Sexton
# Corey Anderson
# Michel Quinones
# Yao Zhikui
# Brock Larson
# Bryan Caraway
# Yves Edwards
# Cortney Casey
# Andrei Semenov
# John Kolosci
# Andre Ewell
# Dennis Siver
# Daron Cruickshank
# Tom Niinimaki
# Soa Palelei
# Keiichiro Yamamiya
# Tony Gravely
# Josh Stuart
# Kyler Phillips
# Steve Lopez
# Jonathan Wiezorek
# Josh Grispi
# Julio Paulino
# Antonio Arroyo
# Matt Hughes
# Edward Faaloloto
# Travis Lutter
# James Vick
# Tom Murphy
# Pete Williams
# Kajan Johnson
# Cris Cyborg
# Holly Holm
# Marcin Prachnio
# Jacob Kilburn
# Brandon Thatch
# Ken Shamrock
# Junior Dos Santos
# Lance Gibson
# Yoshiki Takahashi
# Phillipe Nover
# Abner Lloveras
# Michinori Tanaka
# Brock Jardine
# Edson Barboza
# Punahele Soriano
# Georges St-Pierre
# Darren Uyenoyama
# Joe Duffy
# Ariane Lipski
# Uriah Hall
# Pat Barry
# Keita Nakamura
# Cory Sandhagen
# Victor Valimaki
# Matt Lucas
# Royce Alger
# Andrew Holbrook
# Dan Moret
# Marcelo Mello
# Bethe Correia
# Josh Culibao
# Logan Clark
# Tomasz Drwal
# Ericka Almeida
# Matt Schnell
# Misha Cirkunov
# Brad Morris
# Tom Watson
# Jay Cucciniello
# Kevin Randleman
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-0e8e3020bc22> in <module>
#       2
#       3 for name in fighters.Name:
# ----> 4     print(name)
#       5     temp = final_df[final_df['Fighter'] == name]
#       6     try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\[Lance]\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~\AppData\Local\Continuum\anaconda3\envs\[Lance]\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\AppData\Local\Continuum\anaconda3\envs\[Lance]\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\AppData\Local\Continuum\anaconda3\envs\[Lance]\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
latest_match_db = pd.DataFrame()

# %%
temp = final_df[final_df['Fighter'] == name]
latest = temp.iloc[-1, :]

# %%
latest_match_db = latest_match_db.append(latest)

# %%
latest_match_db
# Out:
#              DOB             Fighter  Height            R_fighter  Reach  \
# 28    26-08-1994       Gabriel Silva    66.0       Kyler Phillips   71.0
# 33    20-09-1989          Aalon Cruz    72.0        Spike Carlyle   78.0
# 258   05-11-1986          Davi Ramos    66.0      Islam Makhachev   70.0
# 3966  17-07-1976       Sean McCorkle    79.0  Christian Morecraft   81.0
# 1698  28-02-1991       Glaico Franca    72.0     Gregor Gillespie   77.0
# ...          ...                 ...     ...                  ...    ...
# 2959  03-12-1977  Cristiano Marcello    69.0          Joe Proctor   72.0
# 1670  26-12-1991      Albert Tumenov    61.0         Leon Edwards   73.0
# 2362  20-06-1978     Rampage Jackson    73.0      Rampage Jackson   73.0
# 2665  06-01-1983      Johnny Bedford    61.0           Rani Yahya   71.0
# 2371  14-04-1977     Jessica Rakoczy    67.0   Valerie Letourneau   68.0
#
#          Stance  Weight Winner    age  avg_cum_Body Attempts  ...  eff_ground  \
# 28     Orthodox   135.0    win  25.53                   0.67  ...        0.00
# 33       Switch   145.0    win  30.46                  28.17  ...        0.00
# 258    Orthodox   155.0    win  32.86                   8.72  ...        0.86
# 3966   Orthodox   265.0    win  34.71                   0.00  ...        0.50
# 1698        NaN   155.0    win  25.59                   6.05  ...        0.67
# ...         ...     ...    ...    ...                    ...  ...         ...
# 2959   Orthodox   155.0    win  36.23                  11.62  ...        0.33
# 1670   Orthodox   170.0    win  24.80                   9.81  ...        0.46
# 2362   Orthodox   205.0    win  36.87                   6.93  ...        0.69
# 2665   Orthodox   135.0    win  31.71                  18.54  ...        0.67
# 2371   Orthodox   115.0    win  38.05                   6.02  ...        0.00
#
#       eff_head  eff_hits  eff_leg  eff_sig_str  eff_tds  loss  match_time  \
# 28        0.50      0.76     1.00         0.50     0.17   1.0       15.00
# 33        0.50      0.17     0.00         0.17     0.00   0.0        1.42
# 258       0.39      0.47     0.91         0.43     0.53   1.0       15.00
# 3966      0.31      0.47     0.00         0.31     0.33   1.0        9.17
# 1698      0.26      0.56     0.81         0.43     0.42   1.0       15.00
# ...        ...       ...      ...          ...      ...   ...         ...
# 2959      0.31      0.40     0.67         0.35     0.14   2.0       15.00
# 1670      0.38      0.44     0.85         0.43     0.20   2.0       13.02
# 2362      0.33      0.54     0.98         0.43     0.30   5.0       15.00
# 2665      0.42      0.59     0.83         0.51     0.62   2.0        7.07
# 2371      1.00      0.89     0.00         0.80     0.00   1.0       15.00
#
#       streak  win
# 28      -1.0  0.0
# 33       0.0  0.0
# 258      4.0  4.0
# 3966    -1.0  1.0
# 1698    -1.0  1.0
# ...      ...  ...
# 2959    -1.0  1.0
# 1670    -1.0  5.0
# 2362    -3.0  7.0
# 2665    -3.0  2.0
# 2371    -1.0  0.0
#
# [2018 rows x 47 columns]

# %%
final_columns = ['Winner', 'R_fighter', 'Fighter', 'DOB', 'Height', 'Reach', 'Stance',
       'Weight', 'date', 'match_time', 'age', 'loss', 'win', 'draws', 'streak',
       'cum_match_time', 'avg_cum_KD', 'avg_cum_Sub. att', 'avg_cum_Pass',
       'avg_cum_Rev.', 'avg_cum_Sig. str. Hits', 'avg_cum_Sig. str. Attempts',
       'avg_cum_Total str. Hits', 'avg_cum_Total str. Attempts',
       'avg_cum_Td Hits', 'avg_cum_Td Attempts', 'avg_cum_Head Hits',
       'avg_cum_Head Attempts', 'avg_cum_Body Hits', 'avg_cum_Body Attempts',
       'avg_cum_Leg Hits', 'avg_cum_Leg Attempts', 'avg_cum_Distance Hits',
       'avg_cum_Distance Attempts', 'avg_cum_Clinch Hits',
       'avg_cum_Clinch Attempts', 'avg_cum_Ground Hits',
       'avg_cum_Ground Attempts', 'eff_sig_str', 'eff_hits', 'eff_tds',
       'eff_head', 'eff_leg', 'eff_body', 'eff_distance', 'eff_clinch',
       'eff_ground']

final_columns_1 = ['{}.1'.format(item) for item in final_columns]

# %%
pd.set_option('display.max_rows', 100)

reformat_final_df = pd.DataFrame()

#For every fight_index, there are exactly two fighers that participated. Combine them into one fight observation:
for item in set(final_df.index):
    temp = pd.DataFrame(final_df.loc[item].iloc[0, :]).T
    temp1 = pd.DataFrame(final_df.loc[item].iloc[1, :]).T

    temp.columns = final_columns
    temp1.columns = final_columns_1
    
    combined = pd.concat([temp, temp1], axis = 1)
    reformat_final_df = pd.concat([reformat_final_df, combined], axis = 0)

# %%
#reformat_final_df.to_csv('../Data/unformatted_final.csv')

# %% [markdown]
# # Format final df:

# %%
#reformat_final_df = pd.read_csv('Data/unformatted_final.csv', index_col = 0)
#reformat_final_df.tail(5)

# %%
drop_columns = ['Winner.1', 'R_fighter.1', 'match_time', 'match_time.1', 'DOB', 'DOB.1', 'date', 'date.1']
reformat_final_df.drop(drop_columns, axis = 1, inplace = True)

# %%
reformat_final_df.columns
# Out:
# Index(['Winner', 'R_fighter', 'Fighter', 'Height', 'Reach', 'Stance', 'Weight',
#        'age', 'loss', 'win', 'draws', 'streak', 'cum_match_time', 'avg_cum_KD',
#        'avg_cum_Sub. att', 'avg_cum_Pass', 'avg_cum_Rev.',
#        'avg_cum_Sig. str. Hits', 'avg_cum_Sig. str. Attempts',
#        'avg_cum_Total str. Hits', 'avg_cum_Total str. Attempts',
#        'avg_cum_Td Hits', 'avg_cum_Td Attempts', 'avg_cum_Head Hits',
#        'avg_cum_Head Attempts', 'avg_cum_Body Hits', 'avg_cum_Body Attempts',
#        'avg_cum_Leg Hits', 'avg_cum_Leg Attempts', 'avg_cum_Distance Hits',
#        'avg_cum_Distance Attempts', 'avg_cum_Clinch Hits',
#        'avg_cum_Clinch Attempts', 'avg_cum_Ground Hits',
#        'avg_cum_Ground Attempts', 'eff_sig_str', 'eff_hits', 'eff_tds',
#        'eff_head', 'eff_leg', 'eff_body', 'eff_distance', 'eff_clinch',
#        'eff_ground', 'Fighter.1', 'Height.1', 'Reach.1', 'Stance.1',
#        'Weight.1', 'age.1', 'loss.1', 'win.1', 'draws.1', 'streak.1',
#        'cum_match_time.1', 'avg_cum_KD.1', 'avg_cum_Sub. att.1',
#        'avg_cum_Pass.1', 'avg_cum_Rev..1', 'avg_cum_Sig. str. Hits.1',
#        'avg_cum_Sig. str. Attempts.1', 'avg_cum_Total str. Hits.1',
#        'avg_cum_Total str. Attempts.1', 'avg_cum_Td Hits.1',
#        'avg_cum_Td Attempts.1', 'avg_cum_Head Hits.1',
#        'avg_cum_Head Attempts.1', 'avg_cum_Body Hits.1',
#        'avg_cum_Body Attempts.1', 'avg_cum_Leg Hits.1',
#        'avg_cum_Leg Attempts.1', 'avg_cum_Distance Hits.1',
#        'avg_cum_Distance Attempts.1', 'avg_cum_Clinch Hits.1',
#        'avg_cum_Clinch Attempts.1', 'avg_cum_Ground Hits.1',
#        'avg_cum_Ground Attempts.1', 'eff_sig_str.1', 'eff_hits.1', 'eff_tds.1',
#        'eff_head.1', 'eff_leg.1', 'eff_body.1', 'eff_distance.1',
#        'eff_clinch.1', 'eff_ground.1'],
#       dtype='object')

# %% [markdown]
# # Recombine Relevant Data --> To File:

# %%
combined_df['num_rounds'] = combined_df['format'].apply(lambda x: int(x[0]) if x[0] != 'N' else 1)
combined_df.reset_index(drop = True, inplace = True)

# %%
keep_columns = ['WEIGHT_CLASS', 'title_bout', 'location', 'attendance', 'num_rounds']
event_attr = combined_df[keep_columns].copy()

# %%
reformat_final_df = pd.concat([reformat_final_df, event_attr], axis = 1)

# %%
winner = []
for index, row in reformat_final_df.iterrows():
    
    if row['Winner'] != 'win':
        winner.append(99999)
    
    elif (row['R_fighter'] == row['Fighter']):
        winner.append(0)
    else:
        winner.append(1)
        
reformat_final_df['label'] = winner

# %%
reformat_final_df['matches'] = reformat_final_df['win'] + reformat_final_df['loss'] + reformat_final_df['draws']+1
reformat_final_df['matches.1'] = reformat_final_df['win.1'] + reformat_final_df['loss.1'] + reformat_final_df['draws.1']+1

# %%
reformat_final_df.to_csv('../Data/to_vis.csv')
